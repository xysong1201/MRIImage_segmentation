# %%
import torch.nn as nn
import os
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from skimage import io, transform
import utils_xy
from torchvision import transforms, utils
import torch
import torch.nn.functional as F
import numpy as np
import nibabel as nib
import UNet3D
from random import randint
from PIL import Image

# %%
gpu_id = 1
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_id)

device = torch.device('cuda')
print (device)
# Out:
# cuda

# %% [markdown]
# ### I. Data Loading

# %%
sub_dir = '/home/xiaoyu/ds-hcp/T1_image'
label_dir = '/home/xiaoyu/ds-hcp/parc_5'

# %%
sub_list = os.listdir(sub_dir)
print('Subject num:')
print(len(sub_list))
label_list = os.listdir(label_dir)
print('\nLabel num:')
print(len(label_list))
# Out:
# Subject num:
# 330
#
# Label num:
# 330

# %% [markdown]
# #### Each pixel in the slice grayscale image also represents a voxel, because this 2D image represents a slice from the 3D image with a certain thickness.

# %%
index = randint(0,329)
sub_str = sub_list[index]
print(sub_str)

# get the tensor data of the random subject
sub_nifti = nib.load(os.path.join(sub_dir,sub_str))
sub_arr = sub_nifti.get_fdata()
sub_tensor = torch.from_numpy(sub_arr)
print(sub_tensor.size())
# Out:
# sub-783462_T1w.nii.gz
# torch.Size([182, 217, 182])

# %% [markdown]
# ### II. Slice the 3D MRI T1w data
# Slice the 3D MRI T1w data, and save the slices into 3 different folders
# #### Axial plane. Get 182 images, for each image, size is 182x217

# %%
for i in range(182):
    sub_slice = sub_tensor[:,:,i]
    sub_arr = sub_slice.byte().numpy()
    sub_im = Image.fromarray(sub_arr)
    sub_im.save("/home/xiaoyu/ds-hcp/axial_slices/slice_{}.jpg".format(i))

# %%
axial_dir = '/home/xiaoyu/ds-hcp/axial_slices'

# %%
axial_list = os.listdir(axial_dir)
print('axial slices num:',len(axial_list))

# Pick a random example
index = randint(0,181)
axial_str = axial_list[index]
axial_arr = io.imread(os.path.join(axial_dir, axial_str))
print('\ndata type: ', axial_arr.dtype)

# make tensor from the numpy array
axial_tensor = torch.from_numpy(axial_arr)

# observe the data size 
print('\ndata size: ', axial_tensor.size())
# Out:
# axial slices num: 182
#
# data type:  uint8
#
# data size:  torch.Size([182, 217])

# %% [markdown]
# #### sagittal plane, get 217 images, image size: 182x182

# %%
for i in range(217):
    sub_slice = sub_tensor[:,i,:]
    sub_arr = sub_slice.byte().numpy()
    sub_im = Image.fromarray(sub_arr)
    sub_im.save("/home/xiaoyu/ds-hcp/sagittal_slices/slice_{}.jpg".format(i))

# %%
sagittal_dir = '/home/xiaoyu/ds-hcp/sagittal_slices'

# %%
sagittal_list = os.listdir(sagittal_dir)
print('sagittal slices num:',len(sagittal_list))

# Pick a random example
index = randint(0,216)
sagittal_str = sagittal_list[index]
sagittal_arr = io.imread(os.path.join(sagittal_dir, sagittal_str))
print('\ndata type: ', sagittal_arr.dtype)

# make tensor from the numpy array
sagittal_tensor = torch.from_numpy(sagittal_arr)

# observe the data size 
print('\ndata size: ', sagittal_tensor.size())
# Out:
# sagittal slices num: 217
#
# data type:  uint8
#
# data size:  torch.Size([182, 182])

# %% [markdown]
# #### coronal plane

# %%
for i in range(182):
    sub_slice = sub_tensor[i,:,:]
    sub_arr = sub_slice.byte().numpy()
    sub_im = Image.fromarray(sub_arr)
    sub_im.save("/home/xiaoyu/ds-hcp/coronal_slices/slice_{}.jpg".format(i))

# %%
coronal_dir = '/home/xiaoyu/ds-hcp/coronal_slices'

# %%
coronal_list = os.listdir(coronal_dir)
print('coronal slices num:',len(coronal_list))

# Pick a random example
index = randint(0,181)
coronal_str = sagittal_list[index]
coronal_arr = io.imread(os.path.join(coronal_dir, coronal_str))
print('\ndata type: ', coronal_arr.dtype)

# make tensor from the numpy array
coronal_tensor = torch.from_numpy(coronal_arr)

# observe the data size 
print('\ndata size: ', coronal_tensor.size())
# Out:
# coronal slices num: 182
#
# data type:  uint8
#
# data size:  torch.Size([217, 182])

# %% [markdown]
# ### Data observation

# %% [markdown]
# The dataset containing a subset of the Human Connectome Project data.
# It contains a total of 285 participants and a total of 330 cases.
#
# The images for one case are stored in its own specific folder, i.e. sub-XX where XX is the HCP participant labell. Note that 45 of them (distinguished in their name by *-V2) are follow-up scans of the same participant. Thus, if you want to consider only one case per participant, you should discard the *-V2s.
#
# - sub-XX_T1w.nii.gz which is the original T1w image (input of the system)
# - sub-XX_T1w._brainmask.nii.gz which is the brainmask used for the generation of the 5 different scales of parcellation
# - sub-XX_class-CSF_T1w and sub_class-WM_T1w are masks of the CSF/ White Matter tissues estimated by Freesurfer during the parcellation pipeline..
# - sub-XX_parc_scaleZ which is the parcellation (labels) for scale Z. scale1 corresponds to the 83 labels generated by freesurfer. scale2->5 correspond to parcellations at a finer scale. I guess we could start using scale1 as the output of the system.

# %%
 def show_slices(slices):
    """ Function to display row of image slices """
    fig, axes = plt.subplots(1, len(slices))
    for i, slice in enumerate(slices):
        axes[i].imshow(slice)

# %%
for i in range(len(img_list)):
    img_str = img_list[i]
    print(img_str)
    
    img_nifti = nib.load(os.path.join(sub_dir,img_str))
    
    img_header = img_nifti.header
#     print(img_header)
    
    img_arr = img_nifti.get_fdata()
    img_tensor = torch.from_numpy(img_arr)
   
    print(img_tensor.size())
# Out:
# sub-129533_class-WM_T1w.nii.gz
# torch.Size([182, 217, 182])
# sub-129533_parc_scale3.nii.gz
# torch.Size([182, 217, 182])
# sub-129533_parc_scale2.nii.gz
# torch.Size([182, 217, 182])
# sub-129533_parc_scale1.nii.gz
# torch.Size([182, 217, 182])
# sub-129533_parc_scale5.nii.gz
# torch.Size([182, 217, 182])
# sub-129533_T1w_brainmask.nii.gz
# torch.Size([182, 217, 182])
# sub-129533_class-CSF_T1w.nii.gz
# torch.Size([182, 217, 182])
# sub-129533_parc_scale4.nii.gz
# torch.Size([182, 217, 182])
# sub-129533_T1w.nii.gz
# torch.Size([182, 217, 182])

# %% [markdown]
# ### Observe the original T1w image

# %%
img_str = img_list[-1]
print(img_str)
# Out:
# sub-129533_T1w.nii.gz

# %%
T1w_nifti = nib.load(os.path.join(sub_dir,img_str))
    
T1w_header = T1w_nifti.header

T1w_arr = T1w_nifti.get_fdata()
T1w_tensor = torch.from_numpy(T1w_arr)
print(img_tensor.size())
# Out:
# torch.Size([182, 217, 182])

# %%
for i in range(181):
    if i %50 ==49:
        plt.subplot(1,3,1)
        plt.imshow(T1w_tensor[:,i,:])
        plt.subplot(1,3,2)
        plt.imshow(T1w_tensor[i])
        plt.subplot(1,3,3)
        plt.imshow(T1w_tensor[:,:,i])
        plt.pause(0.5)

# %% [markdown]
# ### Observe the brainmask generated by FreeSurfer

# %%
brainmask_str = img_list[5]
print(brainmask_str)
# Out:
# sub-129533_T1w_brainmask.nii.gz

# %%
brainmask_nifti = nib.load(os.path.join(sub_dir,brainmask_str ))
    
brainmask_header = brainmask_nifti.header

brainmask_arr = brainmask_nifti.get_fdata()
brainmask_tensor = torch.from_numpy(brainmask_arr)
print(img_tensor.size())
# Out:
# torch.Size([182, 217, 182])

# %%
for i in range(181):
    if i %50 ==49:
        plt.subplot(1,3,1)
        plt.imshow(brainmask_tensor[:,i,:])
        plt.subplot(1,3,2)
        plt.imshow(brainmask_tensor[i])
        plt.subplot(1,3,3)
        plt.imshow(brainmask_tensor[:,:,i])
        plt.pause(0.5)

# %% [markdown]
# ### Observe the CSF / WM

# %%
csf_str = img_list[6]
print(csf_str)
# Out:
# sub-129533_class-CSF_T1w.nii.gz

# %%
csf_nifti = nib.load(os.path.join(sub_dir,csf_str))  
csf_arr = csf_nifti.get_fdata()
csf_tensor = torch.from_numpy(csf_arr)

# %%
for i in range(181):
    if i %50 ==49:
        plt.subplot(1,3,1)
        plt.imshow(csf_tensor[:,i,:])
        plt.subplot(1,3,2)
        plt.imshow(csf_tensor[i])
        plt.subplot(1,3,3)
        plt.imshow(csf_tensor[:,:,i])
        plt.pause(0.5)

# %%
wm_str = img_list[0]
print(wm_str)
# Out:
# sub-129533_class-WM_T1w.nii.gz

# %%
wm_nifti = nib.load(os.path.join(sub_dir,wm_str))  
wm_arr = wm_nifti.get_fdata()
wm_tensor = torch.from_numpy(wm_arr)

# %%
for i in range(181):
    if i %50 ==49:
        plt.subplot(1,3,1)
        plt.imshow(wm_tensor[:,i,:])
        plt.subplot(1,3,2)
        plt.imshow(wm_tensor[i])
        plt.subplot(1,3,3)
        plt.imshow(wm_tensor[:,:,i])
        plt.pause(0.5)

# %% [markdown]
# ### Observe the parcellation of the scale 5

# %%
par5_str = img_list[4]
print(par5_str)
# Out:
# sub-129533_parc_scale5.nii.gz

# %%
par5_nifti = nib.load(os.path.join(sub_dir,par5_str))  
par5_arr = par5_nifti.get_fdata()
par5_tensor = torch.from_numpy(par5_arr)

# %%
for i in range(181):
    if i %50 ==49:
        plt.subplot(1,3,1)
        plt.imshow(par5_tensor[:,i,:])
        plt.subplot(1,3,2)
        plt.imshow(par5_tensor[i])
        plt.subplot(1,3,3)
        plt.imshow(par5_tensor[:,:,i])
        plt.pause(0.5)

# %% [markdown]
# ### Find the unique color in parcellation 5, i.e the class.
# We can slice the 3d image along 3 dimensions. and For each dimension, it will be sliced into 100 image for example.

# %%
slices = torch.tensor([])
print(par5_tensor.size())
print(len(par5_tensor))
for idx in range(181):
    slices = par5_tensor[idx,:,:]
    







for i in range(len(img_list)):
    img_arr = io.imread(os.path.join(img_dir, img_list[i]))
    img_tensor = torch.from_numpy(np.uint8(img_arr))
    img_tensor = img_tensor.permute(2,0,1)
    
    mask_str = mask_list[i]
    mask_arr = io.imread(os.path.join(mask_dir, mask_str))
    mask_tensor = torch.from_numpy(mask_arr)
    unique_color = torch.unique(mask_tensor).type(torch.FloatTensor)
    colors = torch.cat((colors,unique_color))
colors = torch.unique(colors)
print(colors)
print(colors.dtype)
# Out:
# torch.Size([182, 217, 182])
# 182
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-fefcd3d2ebf0> in <module>
#       3 print(len(brainmask_tensor))
#       4 for i in range(len(img_list)):
# ----> 5     img_arr = io.imread(os.path.join(img_dir, img_list[i]))
#       6     img_tensor = torch.from_numpy(np.uint8(img_arr))
#       7     img_tensor = img_tensor.permute(2,0,1)
#
# NameError: name 'img_dir' is not defined

# %% [markdown]
# ### Define the dataset class for training

# %%
class TrainDataset(Dataset):
    """Training dataset with mask image mapping to classes"""
    def __init__(self, img_dir, mask_dir, transform=None):
        """
        Args:
            train_dir (string): Directory with training images
            transform (callable): Optional transform to be applied on a sample
            semantic_dir (string): Directory with semantic segmentation training image
        """
        self.img_dir = img_dir
        self.transform = transform
        self.mask_dir = mask_dir
        
        
    def __len__(self):
        img_list = os.listdir(self.img_dir)
        return len(img_list)
    
    def __getitem__(self, idx):
        img_list = sorted(os.listdir(img_dir))
        mask_list = sorted(os.listdir(mask_dir))
        
        img_str = img_list[idx]
        img_arr = io.imread(os.path.join(img_dir, img_str))
        img_tensor = torch.from_numpy(np.uint8(img_arr))
        img_tensor = img_tensor.permute(2,0,1)
        
        mask_str = mask_list[idx]
        mask_arr = io.imread(os.path.join(mask_dir, mask_str))
        mask_tensor = torch.from_numpy(mask_arr)
        
        # after the compose, the mask value range is [0,1], the data type is torch.float32
        compose = transforms.Compose([transforms.ToPILImage(),
                                      transforms.Resize((384,384),interpolation=Image.NEAREST), 
                                      transforms.ToTensor()])
        
        mask_tensor = torch.unsqueeze(mask_tensor, dim = 0)
        mask_tensor = compose(mask_tensor)
        mask_tensor = mask_tensor.squeeze()
        
        mask_tensor = torch.round(mask_tensor / 0.3).long()-1
      
        sample = {'image':img_tensor, 'mask':mask_tensor}
        
        if self.transform:
            image = self.transform(img_tensor)
            sample = {'image':image, 'mask':mask_tensor}
        return sample
