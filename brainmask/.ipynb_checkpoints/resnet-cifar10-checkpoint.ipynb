# %%
import torch
import numpy as np
import os.path
import utils
import time

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# ### Download the CIFAR dataset
# * 50000 32 * 32 RGB training image
# * 10000 32 * 32 RGB test image

# %%
from utils import check_cifar_dataset_exists
data_path=check_cifar_dataset_exists()

train_data=torch.load(data_path+'cifar/train_data.pt')
train_label=torch.load(data_path+'cifar/train_label.pt')
test_data=torch.load(data_path+'cifar/test_data.pt')
test_label=torch.load(data_path+'cifar/test_label.pt')

print(train_data.size())
print(train_label.size())
print(test_data.size())
# Out:
# torch.Size([50000, 3, 32, 32])
# torch.Size([50000])
# torch.Size([10000, 3, 32, 32])

# %% [markdown]
# ### Compute average pixel intensity over all training set and all channels

# %%
mean= train_data.mean()

print(mean)
# Out:
# tensor(0.4733)

# %% [markdown]
# ### Compute standard deviation

# %%
std= train_data.std()

print(std)
# Out:
# tensor(0.2516)

# %% [markdown]
# ### Make a Resnet convnet Class

# %%
# The BasicBlock is the repeated block in Resnet.
class BasicBlock(nn.Module):
    
    def __init__(self, in_channels):
        super().__init__()
        
        # block 1 :  channel x 32 x 32 -> channel x 32 x 32 -> channel x 32 x 32 (2 layers)
        self.residual_function = nn.Sequential(
            nn.Conv2d(in_channels, in_channels, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(in_channels),
            nn.ReLU(inplace = True),
            nn.Conv2d(in_channels,in_channels, kernel_size=3, stride = 1, padding=1, bias=False),
            nn.BatchNorm2d(in_channels)
        )

        # identity shorcut
        self.shortcut = nn.Sequential()
        
    def forward(self, x):
        return nn.ReLU(inplace=True)(self.residual_function(x) + self.shortcut(x))

# %%
class ResNet(nn.Module):

    def __init__(self, num_classes=10):
        super().__init__()
        
        # income conv 
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, padding=1, stride = 1, bias = False),
            nn.BatchNorm2d(16),
            nn.ReLU(inplace=True))
        
        self.conv2 = BasicBlock(16)
        self.conv2_1 = BasicBlock(16)
        self.conv2_2 = BasicBlock(16)
        
        self.conv3 = nn.Conv2d(16, 32, kernel_size = 3, stride = 2, padding = 1) # subsampling using a stride of 2.
        self.conv4 = BasicBlock(32)
        self.conv4_1 = BasicBlock(32)
        self.conv4_2 = BasicBlock(32)
        
        self.conv5 = nn.Conv2d(32, 64, kernel_size = 3, stride = 2, padding = 1) # subsampling
        self.conv6 = BasicBlock(64)
        self.conv6_1 = BasicBlock(64)
        self.conv6_2 = BasicBlock(64)
        
#         self.avg_pool = nn.AdaptiveAvgPool2d((8, 8))

        # linear layers:   64 x 8 x 8 --> 4096 --> 10
        self.fc = nn.Linear(4096, 10)
        

    def forward(self, x):
        output = self.conv1(x)
        
        output = self.conv2(output)
        output = self.conv2_1(output)
        output = self.conv2_2(output)
        
        output = self.conv3(output)
        
        output = self.conv4(output)
        output = self.conv4_1(output)
        output = self.conv4_2(output)
        
        output = self.conv5(output)
        
        output = self.conv6(output)
        output = self.conv6_1(output)
        output = self.conv6_2(output)
        output = output.view(output.size(0), -1)
        # bs x 4096 ->  bs * 10
#         print(output.size())

        x = self.fc(output)
        x = F.log_softmax(x, dim =1)

        return x

# %%
model = ResNet()
# print(model)

# %%
utils.display_num_param(model)
# Out:
# There are 356218 (0.36 million) parameters in this neural network

# %%
bs=5
x=torch.rand(bs,3,32,32)
y = model(x)
print(y.size())
# Out:
# torch.Size([5, 10])

# %% [markdown]
# ### Put the network to GPU

# %%
gpu_id = 0
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_id)

device = torch.device('cuda')
print(device)
# Out:
# cuda

# %% [markdown]
# ### Send the weights of the networks to the GPU (as well as the mean and std)

# %%
model = model.to(device)

mean=mean.to(device)

std=std.to(device)

# %% [markdown]
# ### Choose the criterion, learning rate, and batch size.

# %%
criterion = nn.NLLLoss()

my_lr=0.1 

bs= 128

# %% [markdown]
# ### Divide the data to 45k train data and 5k dev data

# %%
dev_data = train_data[45000:50000]
dev_label = train_label[45000:50000]

# %%
train_data = train_data[0:45000]
train_label = train_label[0:45000]

# %%
print(dev_data.size())
print(dev_label.size())
# Out:
# torch.Size([5000, 3, 32, 32])
# torch.Size([5000])

# %% [markdown]
# ### Function to evaluate the network on the test set

# %%
def eval_on_dev_set():

    running_error=0
    num_batches=0

    for i in range(0,5000,bs):

        minibatch_data =  dev_data[i:i+bs]
        minibatch_label = dev_label[i:i+bs]

        minibatch_data=minibatch_data.to(device)
        minibatch_label=minibatch_label.to(device)
        
        inputs = (minibatch_data - mean)/std

        scores= model( inputs ) 

        error = utils.get_error( scores , minibatch_label)

        running_error += error.item()

        num_batches+=1

    total_error = running_error/num_batches
    print( 'error rate on dev set =', total_error*100 ,'percent')

# %% [markdown]
# ### Do 64k passes through the training set. Divide the learning rate by 10 at epoch 32k and 48k

# %%
start=time.time()

for epoch in range(1,64000):
    
    # divide the learning rate by 10 at epoch 32k and 48k
    if epoch==32000 or epoch == 48000:
        my_lr = my_lr / 10
    
    # create a new optimizer at the beginning of each epoch: give the current learning rate. 
    optimizer=torch.optim.SGD( model.parameters() , lr=my_lr, momentum = 0.9, weight_decay = 0.0001 )
        
    # set the running quatities to zero at the beginning of the epoch
    running_loss=0
    running_error=0
    num_batches=0
    
    # set the order in which to visit the image from the training set
    shuffled_indices = torch.randperm(45000)
 
    for count in range(0,45000,bs):
    
        # Set the gradients to zeros
        optimizer.zero_grad()
        
        # create a minibatch       
        indices = shuffled_indices[count:count+bs]
        minibatch_data = train_data[indices]
        minibatch_label = train_label[indices]
        
        # send them to the gpu
        minibatch_data=minibatch_data.to(device)
        minibatch_label=minibatch_label.to(device)
        
        # normalize the minibatch (this is the only difference compared to before!)
        inputs = (minibatch_data - mean)/std
        
        # tell Pytorch to start tracking all operations that will be done on "inputs"
        inputs.requires_grad_()

        # forward the minibatch through the net 
        scores=model( inputs ) 

        # Compute the average of the losses of the data points in the minibatch
        loss =  criterion( scores , minibatch_label) 
        
        # backward pass to compute dL/dU, dL/dV and dL/dW   
        loss.backward()

        # do one step of stochastic gradient descent: U=U-lr(dL/dU), V=V-lr(dL/dU), ...
        optimizer.step()
        

        # START COMPUTING STATS
        
        # add the loss of this batch to the running loss
        running_loss += loss.detach().item()
        
        # compute the error made on this batch and add it to the running error       
        error = utils.get_error( scores.detach() , minibatch_label)
        running_error += error.item()
        
        num_batches+=1        
    
    
    # compute stats for the full training set
    total_loss = running_loss/num_batches
    total_error = running_error/num_batches
    elapsed = (time.time()-start)/60
    

    print('epoch=',epoch, '\t time=', elapsed,'min','\t lr=', my_lr  ,'\t loss=', total_loss , '\t error=', total_error*100 ,'percent')
    eval_on_dev_set() 
    print(' ')
# Out:
# epoch= 1 	 time= 0.10245123306910196 min 	 lr= 0.1 	 loss= 4.065308667719364 	 error= 90.03092448481105 percent
# error rate on dev set = 89.609375 percent
#
# epoch= 2 	 time= 0.2031666874885559 min 	 lr= 0.1 	 loss= 2.3041388473727484 	 error= 89.8037997159091 percent
# error rate on dev set = 90.52734375 percent
#
# epoch= 3 	 time= 0.30463571548461915 min 	 lr= 0.1 	 loss= 2.304587746208364 	 error= 89.98283616859804 percent
# error rate on dev set = 89.58984375 percent
#
# epoch= 4 	 time= 0.4024885376294454 min 	 lr= 0.1 	 loss= 2.3043833293698053 	 error= 90.07136798040433 percent
# error rate on dev set = 90.72265625 percent
#
# epoch= 5 	 time= 0.500160276889801 min 	 lr= 0.1 	 loss= 2.3043890317732636 	 error= 89.91501934149049 percent
# error rate on dev set = 89.609375 percent
#
# epoch= 6 	 time= 0.6023951967557272 min 	 lr= 0.1 	 loss= 2.304490840570493 	 error= 90.04547426646407 percent
# error rate on dev set = 90.3515625 percent
#
# epoch= 7 	 time= 0.7010857184727987 min 	 lr= 0.1 	 loss= 2.304411571811546 	 error= 90.02525252713399 percent
# error rate on dev set = 89.86328125 percent
#
# epoch= 8 	 time= 0.8004796822865804 min 	 lr= 0.1 	 loss= 2.304232579740611 	 error= 90.39269650185649 percent
# error rate on dev set = 89.66796875 percent
#
# epoch= 9 	 time= 0.9030814250310262 min 	 lr= 0.1 	 loss= 2.3045494590293276 	 error= 89.95546283708377 percent
# error rate on dev set = 89.70703125 percent
#
# epoch= 10 	 time= 1.005366031328837 min 	 lr= 0.1 	 loss= 2.3041370802304963 	 error= 89.79442866349761 percent
# error rate on dev set = 90.52734375 percent
#
# epoch= 11 	 time= 1.1096196492513022 min 	 lr= 0.1 	 loss= 2.30438726937229 	 error= 90.04078874872489 percent
# error rate on dev set = 89.609375 percent
#
# epoch= 12 	 time= 1.2059661825497945 min 	 lr= 0.1 	 loss= 2.304265818135305 	 error= 90.0437480346723 percent
# error rate on dev set = 89.78515625 percent
#
# epoch= 13 	 time= 1.3052138805389404 min 	 lr= 0.1 	 loss= 2.3041669496081094 	 error= 89.87926136363636 percent
# error rate on dev set = 89.86328125 percent
#
# epoch= 14 	 time= 1.405220663547516 min 	 lr= 0.1 	 loss= 2.30408920889551 	 error= 89.92488360540433 percent
# error rate on dev set = 90.3515625 percent
#
# epoch= 15 	 time= 1.5025302171707153 min 	 lr= 0.1 	 loss= 2.3045180067420006 	 error= 90.03141769631343 percent
# error rate on dev set = 89.58984375 percent
#
# epoch= 16 	 time= 1.603185482819875 min 	 lr= 0.1 	 loss= 2.3043661747466433 	 error= 90.02451270141385 percent
# error rate on dev set = 89.86328125 percent
#
# epoch= 17 	 time= 1.706633492310842 min 	 lr= 0.1 	 loss= 2.304334879598834 	 error= 89.79122278026558 percent
# error rate on dev set = 90.3515625 percent
#
# epoch= 18 	 time= 1.8096646388371787 min 	 lr= 0.1 	 loss= 26.589523197575048 	 error= 90.22697679359804 percent
# error rate on dev set = 90.72265625 percent
#
# epoch= 19 	 time= 1.9097268184026082 min 	 lr= 0.1 	 loss= 2.304251005703753 	 error= 89.9705058471723 percent
# error rate on dev set = 90.3515625 percent
#
# epoch= 20 	 time= 2.0047790169715882 min 	 lr= 0.1 	 loss= 2.3043672787872227 	 error= 89.96606692671776 percent
# error rate on dev set = 90.17578125 percent
#
# epoch= 21 	 time= 2.104016292095184 min 	 lr= 0.1 	 loss= 2.3044265400279653 	 error= 90.12858073481105 percent
# error rate on dev set = 90.52734375 percent
#
# epoch= 22 	 time= 2.2025198419888814 min 	 lr= 0.1 	 loss= 2.3045504228635267 	 error= 89.81884272599761 percent
# error rate on dev set = 89.78515625 percent
#
# epoch= 23 	 time= 2.303970948855082 min 	 lr= 0.1 	 loss= 2.3044755309820175 	 error= 89.8728495971723 percent
# error rate on dev set = 90.17578125 percent
#
# epoch= 24 	 time= 2.406841270128886 min 	 lr= 0.1 	 loss= 2.304363104430112 	 error= 90.08764401078224 percent
# error rate on dev set = 89.66796875 percent
#
# epoch= 25 	 time= 2.5072948733965554 min 	 lr= 0.1 	 loss= 2.304141816090454 	 error= 89.85386087813161 percent
# error rate on dev set = 89.58984375 percent
#
# epoch= 26 	 time= 2.607030177116394 min 	 lr= 0.1 	 loss= 2.304354723204266 	 error= 90.00799005681817 percent
# error rate on dev set = 90.72265625 percent
#
# epoch= 27 	 time= 2.701235584417979 min 	 lr= 0.1 	 loss= 2.30400383269245 	 error= 89.92562341419134 percent
# error rate on dev set = 90.52734375 percent
#
# epoch= 28 	 time= 2.8056998014450074 min 	 lr= 0.1 	 loss= 2.3043646209619264 	 error= 90.19417810169134 percent
# error rate on dev set = 89.58984375 percent
#
# epoch= 29 	 time= 2.9037795186042787 min 	 lr= 0.1 	 loss= 2.304331889206713 	 error= 90.12241556563161 percent
# error rate on dev set = 89.86328125 percent
#
# epoch= 30 	 time= 3.006589349110921 min 	 lr= 0.1 	 loss= 2.3042246387763456 	 error= 89.86125906760041 percent
# error rate on dev set = 89.58984375 percent
#
# epoch= 31 	 time= 3.106902460257212 min 	 lr= 0.1 	 loss= 2.304431813007051 	 error= 90.08912366222252 percent
# error rate on dev set = 90.52734375 percent
#
# epoch= 32 	 time= 3.2060588002204895 min 	 lr= 0.1 	 loss= 2.3043100888078865 	 error= 89.91107363253832 percent
# error rate on dev set = 89.70703125 percent
#
# epoch= 33 	 time= 3.3006667176882427 min 	 lr= 0.1 	 loss= 2.3046696836298164 	 error= 90.13869159600951 percent
# error rate on dev set = 90.52734375 percent
#
# epoch= 34 	 time= 3.396456408500671 min 	 lr= 0.1 	 loss= 2.304577912119302 	 error= 90.13301965526558 percent
# error rate on dev set = 90.17578125 percent
#
# epoch= 35 	 time= 3.500546089808146 min 	 lr= 0.1 	 loss= 2.304283167828213 	 error= 89.93894017555498 percent
# error rate on dev set = 89.609375 percent
#
# epoch= 36 	 time= 3.6036028981208803 min 	 lr= 0.1 	 loss= 2.304483376443386 	 error= 90.06249013949524 percent
# error rate on dev set = 90.3515625 percent
#
# epoch= 37 	 time= 3.697967028617859 min 	 lr= 0.1 	 loss= 2.3046996132893995 	 error= 89.99442668123679 percent
# error rate on dev set = 89.78515625 percent
#
# epoch= 38 	 time= 3.798646040757497 min 	 lr= 0.1 	 loss= 2.3044558011672716 	 error= 90.11403093622489 percent
# error rate on dev set = 90.52734375 percent
#
# epoch= 39 	 time= 3.900482098261515 min 	 lr= 0.1 	 loss= 2.304132280701941 	 error= 89.97321851890196 percent
# error rate on dev set = 89.70703125 percent
#
# epoch= 40 	 time= 4.000533513228098 min 	 lr= 0.1 	 loss= 2.304450939324769 	 error= 89.9973859671842 percent
# error rate on dev set = 90.17578125 percent
#
# epoch= 41 	 time= 4.102744011084239 min 	 lr= 0.1 	 loss= 2.3045484951951285 	 error= 89.98998776078224 percent
# error rate on dev set = 90.72265625 percent
#
# epoch= 42 	 time= 4.199779550234477 min 	 lr= 0.1 	 loss= 2.3044342656027186 	 error= 90.24497908963399 percent
# error rate on dev set = 90.52734375 percent
#
# epoch= 43 	 time= 4.301079344749451 min 	 lr= 0.1 	 loss= 2.304580657319589 	 error= 89.98875474049287 percent
# error rate on dev set = 90.17578125 percent
#
# epoch= 44 	 time= 4.402835996945699 min 	 lr= 0.1 	 loss= 2.3042985891753975 	 error= 90.13893821022727 percent
# error rate on dev set = 90.3515625 percent
#
# epoch= 45 	 time= 4.504917045434316 min 	 lr= 0.1 	 loss= 2.30399372225458 	 error= 89.89035866477273 percent
# error rate on dev set = 89.86328125 percent
#
# epoch= 46 	 time= 4.604065958658854 min 	 lr= 0.1 	 loss= 2.304305222901431 	 error= 90.34115570512685 percent
# error rate on dev set = 89.53125 percent
#
# epoch= 47 	 time= 4.707608624299367 min 	 lr= 0.1 	 loss= 2.304137456823479 	 error= 90.07777974686839 percent
# error rate on dev set = 90.17578125 percent
#
# epoch= 48 	 time= 4.8067102034886675 min 	 lr= 0.1 	 loss= 2.304370529949665 	 error= 90.11304451322015 percent
# error rate on dev set = 89.66796875 percent
#
# epoch= 49 	 time= 4.9041687170664465 min 	 lr= 0.1 	 loss= 2.304215935820883 	 error= 89.86051925881343 percent
# error rate on dev set = 89.58984375 percent
#
# epoch= 50 	 time= 5.005472501118978 min 	 lr= 0.1 	 loss= 2.3044799945571204 	 error= 89.93647411804308 percent
# error rate on dev set = 89.609375 percent
#
# epoch= 51 	 time= 5.105593486626943 min 	 lr= 0.1 	 loss= 2.30449220741337 	 error= 90.02525252713399 percent
# error rate on dev set = 89.609375 percent
#
# epoch= 52 	 time= 5.205665453275045 min 	 lr= 0.1 	 loss= 2.304433087733659 	 error= 90.24547230113636 percent
# error rate on dev set = 89.58984375 percent
#
# epoch= 53 	 time= 5.305324141184489 min 	 lr= 0.1 	 loss= 2.304428376934745 	 error= 90.07679332386364 percent
# error rate on dev set = 89.58984375 percent
#
# epoch= 54 	 time= 5.408148169517517 min 	 lr= 0.1 	 loss= 2.304646049033512 	 error= 90.18234099176797 percent
# error rate on dev set = 90.52734375 percent
#
# epoch= 55 	 time= 5.505988490581513 min 	 lr= 0.1 	 loss= 2.3046786974776876 	 error= 90.13277304104783 percent
# error rate on dev set = 89.86328125 percent
#
# epoch= 56 	 time= 5.606597630182902 min 	 lr= 0.1 	 loss= 2.30450334941799 	 error= 90.06421638822015 percent
# error rate on dev set = 89.58984375 percent
#
# epoch= 57 	 time= 5.707600657145182 min 	 lr= 0.1 	 loss= 2.304250618273562 	 error= 90.0706281546842 percent
# error rate on dev set = 90.17578125 percent
#
# epoch= 58 	 time= 5.808122022946676 min 	 lr= 0.1 	 loss= 2.304236835376783 	 error= 90.06495619700713 percent
# error rate on dev set = 89.70703125 percent
#
# epoch= 59 	 time= 5.907059601942698 min 	 lr= 0.1 	 loss= 2.3042142885652455 	 error= 90.14411695640196 percent
# error rate on dev set = 89.609375 percent
#
# epoch= 60 	 time= 6.007255017757416 min 	 lr= 0.1 	 loss= 2.304405439306389 	 error= 90.26865332641385 percent
# error rate on dev set = 89.609375 percent
#
# epoch= 61 	 time= 6.107248699665069 min 	 lr= 0.1 	 loss= 2.304424401711334 	 error= 90.06076389077035 percent
# error rate on dev set = 89.58984375 percent
#
# epoch= 62 	 time= 6.207827456792196 min 	 lr= 0.1 	 loss= 2.304761892015284 	 error= 90.13647213578224 percent
# error rate on dev set = 90.17578125 percent
#
# epoch= 63 	 time= 6.3089597702026365 min 	 lr= 0.1 	 loss= 2.304325785826553 	 error= 89.99812579290433 percent
# error rate on dev set = 89.78515625 percent
#
# epoch= 64 	 time= 6.4081672112147015 min 	 lr= 0.1 	 loss= 2.2746281258084555 	 error= 88.26176806945692 percent
# error rate on dev set = 78.8671875 percent
#
# epoch= 65 	 time= 6.508998084068298 min 	 lr= 0.1 	 loss= 2.0546065724708815 	 error= 78.15015388822015 percent
# error rate on dev set = 73.359375 percent
#
# epoch= 66 	 time= 6.606992566585541 min 	 lr= 0.1 	 loss= 1.7961270216513763 	 error= 66.82326190850951 percent
# error rate on dev set = 64.00390625 percent
#
# epoch= 67 	 time= 6.711115312576294 min 	 lr= 0.1 	 loss= 1.6769403459673577 	 error= 61.60753037441861 percent
# error rate on dev set = 59.55078124999999 percent
#
# epoch= 68 	 time= 6.810585343837738 min 	 lr= 0.1 	 loss= 1.601369758559899 	 error= 58.44430635598573 percent
# error rate on dev set = 57.7734375 percent
#
# epoch= 69 	 time= 6.9058152834574384 min 	 lr= 0.1 	 loss= 1.541435488245704 	 error= 55.4640644653277 percent
# error rate on dev set = 55.4296875 percent
#
# epoch= 70 	 time= 7.005593073368073 min 	 lr= 0.1 	 loss= 1.4562520184977488 	 error= 52.434254657815806 percent
# error rate on dev set = 52.55859375000001 percent
#
# epoch= 71 	 time= 7.107090536753336 min 	 lr= 0.1 	 loss= 1.3562624285166913 	 error= 48.573873496868394 percent
# error rate on dev set = 48.2421875 percent
#
# epoch= 72 	 time= 7.206469587484995 min 	 lr= 0.1 	 loss= 1.2806940722194584 	 error= 45.64319957386363 percent
# error rate on dev set = 45.1953125 percent
#
# epoch= 73 	 time= 7.306827493508657 min 	 lr= 0.1 	 loss= 1.2238427874716846 	 error= 43.323617022145875 percent
# error rate on dev set = 42.67578125 percent
#
# epoch= 74 	 time= 7.407666619618734 min 	 lr= 0.1 	 loss= 1.167500783435323 	 error= 41.280233978547834 percent
# error rate on dev set = 40.56640625 percent
#
# epoch= 75 	 time= 7.504466342926025 min 	 lr= 0.1 	 loss= 1.121887350285595 	 error= 39.432656646452166 percent
# error rate on dev set = 39.921875 percent
#
# epoch= 76 	 time= 7.601766947905222 min 	 lr= 0.1 	 loss= 1.0889444498514587 	 error= 38.74881628223441 percent
# error rate on dev set = 38.828125 percent
#
# epoch= 77 	 time= 7.701479836304983 min 	 lr= 0.1 	 loss= 1.0544187572192063 	 error= 37.17423255809329 percent
# error rate on dev set = 38.06640625 percent
#
# epoch= 78 	 time= 7.799314590295156 min 	 lr= 0.1 	 loss= 1.0142550189048052 	 error= 35.84847497669133 percent
# error rate on dev set = 37.44140625 percent
#
# epoch= 79 	 time= 7.898184510072072 min 	 lr= 0.1 	 loss= 0.9794348539276556 	 error= 34.555022875693716 percent
# error rate on dev set = 37.51953125 percent
#
# epoch= 80 	 time= 8.000777530670167 min 	 lr= 0.1 	 loss= 0.9550884936682202 	 error= 33.41175426136363 percent
# error rate on dev set = 35.44921875 percent
#
# epoch= 81 	 time= 8.101073225339254 min 	 lr= 0.1 	 loss= 0.932529532265934 	 error= 32.693388973447405 percent
# error rate on dev set = 35.546875 percent
#
# epoch= 82 	 time= 8.203879423936208 min 	 lr= 0.1 	 loss= 0.9061141015792434 	 error= 31.93753945895217 percent
# error rate on dev set = 36.953125 percent
#
# epoch= 83 	 time= 8.303124451637268 min 	 lr= 0.1 	 loss= 0.8844665979797189 	 error= 31.175278177992865 percent
# error rate on dev set = 32.1484375 percent
#
# epoch= 84 	 time= 8.400502999623617 min 	 lr= 0.1 	 loss= 0.854128481481563 	 error= 30.034722218459304 percent
# error rate on dev set = 33.73046875 percent
#
# epoch= 85 	 time= 8.502592921257019 min 	 lr= 0.1 	 loss= 0.830594916743311 	 error= 29.14052636108615 percent
# error rate on dev set = 31.328125 percent
#
# epoch= 86 	 time= 8.60620857477188 min 	 lr= 0.1 	 loss= 0.8058955823494629 	 error= 28.23819247159091 percent
# error rate on dev set = 31.25 percent
#
# epoch= 87 	 time= 8.70801545381546 min 	 lr= 0.1 	 loss= 0.7762426202270117 	 error= 27.35879301008853 percent
# error rate on dev set = 33.41796875 percent
#
# epoch= 88 	 time= 8.810443170865376 min 	 lr= 0.1 	 loss= 0.7528753906319087 	 error= 26.40467170964588 percent
# error rate on dev set = 31.23046875 percent
#
# epoch= 89 	 time= 8.910878709952037 min 	 lr= 0.1 	 loss= 0.7351889376613227 	 error= 25.867069123143498 percent
# error rate on dev set = 31.34765625 percent
#
# epoch= 90 	 time= 9.010807140668232 min 	 lr= 0.1 	 loss= 0.708221195180985 	 error= 24.833293868736785 percent
# error rate on dev set = 28.085937500000004 percent
#
# epoch= 91 	 time= 9.108114914099376 min 	 lr= 0.1 	 loss= 0.6801266755739396 	 error= 23.905066282234408 percent
# error rate on dev set = 30.25390625 percent
#
# epoch= 92 	 time= 9.206132141749064 min 	 lr= 0.1 	 loss= 0.6673693673854525 	 error= 23.338610712777484 percent
# error rate on dev set = 29.66796875 percent
#
# epoch= 93 	 time= 9.305056472619375 min 	 lr= 0.1 	 loss= 0.6558695084161379 	 error= 22.740342874418605 percent
# error rate on dev set = 29.843750000000004 percent
#
# epoch= 94 	 time= 9.40548096895218 min 	 lr= 0.1 	 loss= 0.6202917513014241 	 error= 21.808416193181817 percent
# error rate on dev set = 29.39453125 percent
#
# epoch= 95 	 time= 9.507068638006846 min 	 lr= 0.1 	 loss= 0.610575750046833 	 error= 21.54898594387553 percent
# error rate on dev set = 29.27734375 percent
#
# epoch= 96 	 time= 9.606165937582652 min 	 lr= 0.1 	 loss= 0.5964291872118007 	 error= 20.92556423422965 percent
# error rate on dev set = 30.29296875 percent
#
# epoch= 97 	 time= 9.708519923686982 min 	 lr= 0.1 	 loss= 0.5738302783363245 	 error= 20.155411535366017 percent
# error rate on dev set = 28.73046875 percent
#
# epoch= 98 	 time= 9.804895993073782 min 	 lr= 0.1 	 loss= 0.5528641072186556 	 error= 19.30807094005021 percent
# error rate on dev set = 29.8828125 percent
#
# epoch= 99 	 time= 9.906014001369476 min 	 lr= 0.1 	 loss= 0.5428448801182888 	 error= 19.119910032234408 percent
# error rate on dev set = 28.7890625 percent
#
# epoch= 100 	 time= 10.004687066872915 min 	 lr= 0.1 	 loss= 0.5237149084833536 	 error= 18.36529355496168 percent
# error rate on dev set = 28.7890625 percent
#
# epoch= 101 	 time= 10.103946220874786 min 	 lr= 0.1 	 loss= 0.5105385436591777 	 error= 17.96628392555497 percent
# error rate on dev set = 28.867187500000004 percent
#
# epoch= 102 	 time= 10.204233276844025 min 	 lr= 0.1 	 loss= 0.47511988607319916 	 error= 16.744101166047834 percent
# error rate on dev set = 28.7109375 percent
#
# epoch= 103 	 time= 10.301140157381694 min 	 lr= 0.1 	 loss= 0.4815664936534383 	 error= 16.85162167996168 percent
# error rate on dev set = 29.1796875 percent
#
# epoch= 104 	 time= 10.401182798544566 min 	 lr= 0.1 	 loss= 0.47698510493236507 	 error= 16.806985878131606 percent
# error rate on dev set = 29.746093750000004 percent
#
# epoch= 105 	 time= 10.502660008271535 min 	 lr= 0.1 	 loss= 0.4492535060271621 	 error= 15.885416672311045 percent
# error rate on dev set = 28.6328125 percent
# epoch= 106 	 time= 10.60258073012034 min 	 lr= 0.1 	 loss= 0.4364836711267179 	 error= 15.423275716602802 percent
# error rate on dev set = 28.203125 percent
#
# epoch= 107 	 time= 10.701287778218587 min 	 lr= 0.1 	 loss= 0.44212466838176956 	 error= 15.497504344040697 percent
# error rate on dev set = 29.12109375 percent
#
# epoch= 108 	 time= 10.800606667995453 min 	 lr= 0.1 	 loss= 0.4210280294699425 	 error= 14.652876420454545 percent
# error rate on dev set = 29.824218749999996 percent
#
# epoch= 109 	 time= 10.902257247765858 min 	 lr= 0.1 	 loss= 0.4119687943549996 	 error= 14.460276592184195 percent
# error rate on dev set = 29.47265625 percent
#
# epoch= 110 	 time= 11.002518419424693 min 	 lr= 0.1 	 loss= 0.4132235965860838 	 error= 14.613665962083774 percent
# error rate on dev set = 30.507812499999996 percent
#
# epoch= 111 	 time= 11.101859068870544 min 	 lr= 0.1 	 loss= 0.4081137058409778 	 error= 14.397391880100423 percent
# error rate on dev set = 30.019531249999996 percent
#
# epoch= 112 	 time= 11.20203362305959 min 	 lr= 0.1 	 loss= 0.4071724160405045 	 error= 14.306147413497621 percent
# error rate on dev set = 30.25390625 percent
#
# epoch= 113 	 time= 11.30079762538274 min 	 lr= 0.1 	 loss= 0.3817810787903992 	 error= 13.236120969734408 percent
# error rate on dev set = 28.769531250000004 percent
#
# epoch= 114 	 time= 11.396867986520132 min 	 lr= 0.1 	 loss= 0.3800787169232287 	 error= 13.293580338358879 percent
# error rate on dev set = 29.86328125 percent
#
# epoch= 115 	 time= 11.499782816569011 min 	 lr= 0.1 	 loss= 0.3747070507061752 	 error= 12.94857756319371 percent
# error rate on dev set = 30.332031250000004 percent
#
# epoch= 116 	 time= 11.595398032665253 min 	 lr= 0.1 	 loss= 0.36574484062889084 	 error= 12.757210772145877 percent
# error rate on dev set = 31.191406249999996 percent
#
# epoch= 117 	 time= 11.690728398164113 min 	 lr= 0.1 	 loss= 0.36886300504292274 	 error= 12.833658859811045 percent
# error rate on dev set = 30.234375000000004 percent
#
# epoch= 118 	 time= 11.78613732655843 min 	 lr= 0.1 	 loss= 0.37252317779612815 	 error= 12.92120423167944 percent
# error rate on dev set = 29.042968749999996 percent
#
# epoch= 119 	 time= 11.889639536539713 min 	 lr= 0.1 	 loss= 0.35223296197893267 	 error= 12.347597070038319 percent
# error rate on dev set = 28.964843750000004 percent
#
# epoch= 120 	 time= 11.986934526761372 min 	 lr= 0.1 	 loss= 0.3377262706106359 	 error= 11.755494400858879 percent
# error rate on dev set = 30.234375000000004 percent
#
# epoch= 121 	 time= 12.087231675783793 min 	 lr= 0.1 	 loss= 0.3538179193538698 	 error= 12.354502048004758 percent
# error rate on dev set = 27.91015625 percent
#
# epoch= 122 	 time= 12.188578553994496 min 	 lr= 0.1 	 loss= 0.3202441257466985 	 error= 11.324179291047832 percent
# error rate on dev set = 28.88671875 percent
#
# epoch= 123 	 time= 12.288979840278625 min 	 lr= 0.1 	 loss= 0.33042648978616024 	 error= 11.444276757538319 percent
# error rate on dev set = 28.515625 percent
#
# epoch= 124 	 time= 12.390888047218322 min 	 lr= 0.1 	 loss= 0.30401317766782915 	 error= 10.49829347228462 percent
# error rate on dev set = 27.63671875 percent
#
# epoch= 125 	 time= 12.491944766044616 min 	 lr= 0.1 	 loss= 0.32847493345087225 	 error= 11.210246993736787 percent
# error rate on dev set = 30.722656250000004 percent
#
# epoch= 126 	 time= 12.595379785696666 min 	 lr= 0.1 	 loss= 0.3353289965201508 	 error= 11.488419347866015 percent
# error rate on dev set = 28.7109375 percent
#
# epoch= 127 	 time= 12.695632966359456 min 	 lr= 0.1 	 loss= 0.32856982334686274 	 error= 11.437371762638742 percent
# error rate on dev set = 29.47265625 percent
#
# epoch= 128 	 time= 12.794959990183512 min 	 lr= 0.1 	 loss= 0.33013757913034747 	 error= 11.401860399002379 percent
# error rate on dev set = 30.234375000000004 percent
#
# epoch= 129 	 time= 12.892981429894766 min 	 lr= 0.1 	 loss= 0.31033400795422494 	 error= 10.62578914517706 percent
# error rate on dev set = 30.83984375 percent
#
# epoch= 130 	 time= 12.993293988704682 min 	 lr= 0.1 	 loss= 0.3144923551431434 	 error= 10.914318974722516 percent
# error rate on dev set = 30.0 percent
#
# epoch= 131 	 time= 13.0925106326739 min 	 lr= 0.1 	 loss= 0.2830132420640439 	 error= 9.868459996174682 percent
# error rate on dev set = 30.605468749999996 percent
#
# epoch= 132 	 time= 13.188782489299774 min 	 lr= 0.1 	 loss= 0.30313015121712605 	 error= 10.476345484229652 percent
# error rate on dev set = 29.98046875 percent
#
# epoch= 133 	 time= 13.287925855318706 min 	 lr= 0.1 	 loss= 0.3297184785954993 	 error= 11.176955090327697 percent
# error rate on dev set = 29.98046875 percent
#
# epoch= 134 	 time= 13.3928892771403 min 	 lr= 0.1 	 loss= 0.2989703270776028 	 error= 10.227272727272728 percent
# error rate on dev set = 28.125 percent
#
# epoch= 135 	 time= 13.491244165102641 min 	 lr= 0.1 	 loss= 0.28492480059238995 	 error= 9.745156646452168 percent
# error rate on dev set = 30.09765625 percent
#
# epoch= 136 	 time= 13.590278085072836 min 	 lr= 0.1 	 loss= 0.2921961626164954 	 error= 9.845772165466439 percent
# error rate on dev set = 29.453125000000004 percent
#
# epoch= 137 	 time= 13.692108313242594 min 	 lr= 0.1 	 loss= 0.2919983600731939 	 error= 9.983625313775105 percent
# error rate on dev set = 28.02734375 percent
#
# epoch= 138 	 time= 13.794839708010356 min 	 lr= 0.1 	 loss= 0.26597665100019763 	 error= 8.986101248724895 percent
# error rate on dev set = 30.429687500000004 percent
#
# epoch= 139 	 time= 13.893343615531922 min 	 lr= 0.1 	 loss= 0.27027891108512203 	 error= 9.364395910366015 percent
# error rate on dev set = 30.312499999999996 percent
#
# epoch= 140 	 time= 13.999220558007558 min 	 lr= 0.1 	 loss= 0.287824353129095 	 error= 9.792751734229652 percent
# error rate on dev set = 30.09765625 percent
#
# epoch= 141 	 time= 14.098684159914653 min 	 lr= 0.1 	 loss= 0.2681471056897532 	 error= 9.123707782815803 percent
# error rate on dev set = 29.843750000000004 percent
#
# epoch= 142 	 time= 14.196870589256287 min 	 lr= 0.1 	 loss= 0.27157663608985866 	 error= 9.285235167904334 percent
# error rate on dev set = 30.019531249999996 percent
#
# epoch= 143 	 time= 14.293905369440715 min 	 lr= 0.1 	 loss= 0.2555661065694453 	 error= 8.774759315631607 percent
# error rate on dev set = 29.843750000000004 percent
#
# epoch= 144 	 time= 14.3941020210584 min 	 lr= 0.1 	 loss= 0.2415896057447588 	 error= 8.210769803686576 percent
# error rate on dev set = 29.27734375 percent
#
# epoch= 145 	 time= 14.490913959344228 min 	 lr= 0.1 	 loss= 0.2682589254320853 	 error= 9.06378235667944 percent
# error rate on dev set = 30.332031250000004 percent
#
# epoch= 146 	 time= 14.591684297720592 min 	 lr= 0.1 	 loss= 0.2767950629349798 	 error= 9.307183155959303 percent
# error rate on dev set = 29.296875 percent
#
# epoch= 147 	 time= 14.690434416135153 min 	 lr= 0.1 	 loss= 0.25911803130822425 	 error= 8.77919823608615 percent
# error rate on dev set = 28.02734375 percent
#
# epoch= 148 	 time= 14.787760615348816 min 	 lr= 0.1 	 loss= 0.22207127200354906 	 error= 7.628284801136363 percent
# error rate on dev set = 28.046875 percent
#
# epoch= 149 	 time= 14.890153165658315 min 	 lr= 0.1 	 loss= 0.2523292755940929 	 error= 8.447019010782242 percent
# error rate on dev set = 28.73046875 percent
#
# epoch= 150 	 time= 14.994560396671295 min 	 lr= 0.1 	 loss= 0.25405087300830265 	 error= 8.682035197588531 percent
# error rate on dev set = 29.39453125 percent
#
# epoch= 151 	 time= 15.091526051362356 min 	 lr= 0.1 	 loss= 0.22695209753741932 	 error= 7.741723870011893 percent
# error rate on dev set = 29.843750000000004 percent
#
# epoch= 152 	 time= 15.192795797189076 min 	 lr= 0.1 	 loss= 0.2330180250256407 	 error= 7.988330569456924 percent
# error rate on dev set = 28.92578125 percent
#
# epoch= 153 	 time= 15.292366679509481 min 	 lr= 0.1 	 loss= 0.2544327117926018 	 error= 8.681048774583774 percent
# error rate on dev set = 29.453125000000004 percent
#
# epoch= 154 	 time= 15.393303537368775 min 	 lr= 0.1 	 loss= 0.22397889082574032 	 error= 7.778468270870772 percent
# error rate on dev set = 28.964843750000004 percent
#
# epoch= 155 	 time= 15.491105937957764 min 	 lr= 0.1 	 loss= 0.22661516239697282 	 error= 7.722488553686575 percent
# error rate on dev set = 28.22265625 percent
#
# epoch= 156 	 time= 15.59233835140864 min 	 lr= 0.1 	 loss= 0.22889678363307295 	 error= 7.9116358845071355 percent
# error rate on dev set = 28.88671875 percent
#
# epoch= 157 	 time= 15.690306417147319 min 	 lr= 0.1 	 loss= 0.23683846251912077 	 error= 8.069957386363637 percent
# error rate on dev set = 28.73046875 percent
#
# epoch= 158 	 time= 15.787585079669952 min 	 lr= 0.1 	 loss= 0.23567162494344468 	 error= 8.073163269595666 percent
# error rate on dev set = 30.859375 percent
#
# epoch= 159 	 time= 15.886044963200886 min 	 lr= 0.1 	 loss= 0.2422282176240432 	 error= 8.181423609229652 percent
# error rate on dev set = 29.47265625 percent
#
# epoch= 160 	 time= 15.987226764361063 min 	 lr= 0.1 	 loss= 0.24388803550126878 	 error= 8.41422031887553 percent
# error rate on dev set = 29.042968749999996 percent
#
# epoch= 161 	 time= 16.0860081354777 min 	 lr= 0.1 	 loss= 0.23248239532536405 	 error= 7.8635475852272725 percent
# error rate on dev set = 29.51171875 percent
#
# epoch= 162 	 time= 16.18644646803538 min 	 lr= 0.1 	 loss= 0.22145261318126525 	 error= 7.674153640188954 percent
# error rate on dev set = 27.9296875 percent
#
# epoch= 163 	 time= 16.285010878245036 min 	 lr= 0.1 	 loss= 0.23145405698398297 	 error= 7.837653888220136 percent
# error rate on dev set = 28.3203125 percent
#
# epoch= 164 	 time= 16.38377401034037 min 	 lr= 0.1 	 loss= 0.2011574306419458 	 error= 6.937292844734409 percent
# error rate on dev set = 27.695312500000004 percent
#
# epoch= 165 	 time= 16.486341496308643 min 	 lr= 0.1 	 loss= 0.20118838384620508 	 error= 6.985134546729651 percent
# error rate on dev set = 27.500000000000004 percent
#
# epoch= 166 	 time= 16.5862584233284 min 	 lr= 0.1 	 loss= 0.2264049227603457 	 error= 7.674153640188954 percent
# error rate on dev set = 28.671875000000004 percent
#
# epoch= 167 	 time= 16.686331339677174 min 	 lr= 0.1 	 loss= 0.22913900337351317 	 error= 7.743203521452167 percent
# error rate on dev set = 28.261718749999996 percent
#
# epoch= 168 	 time= 16.78216432730357 min 	 lr= 0.1 	 loss= 0.2160922314400192 	 error= 7.151594063775106 percent
# error rate on dev set = 28.066406249999996 percent
#
# epoch= 169 	 time= 16.880738238493603 min 	 lr= 0.1 	 loss= 0.20711891746825792 	 error= 7.1266867897727275 percent
# error rate on dev set = 28.33984375 percent
#
# epoch= 170 	 time= 16.98215219974518 min 	 lr= 0.1 	 loss= 0.20160544576885348 	 error= 6.8818063390525905 percent
# error rate on dev set = 28.6328125 percent
#
# epoch= 171 	 time= 17.081422281265258 min 	 lr= 0.1 	 loss= 0.2132870850936425 	 error= 7.288214174861257 percent
# error rate on dev set = 28.085937500000004 percent
#
# epoch= 172 	 time= 17.182967925071715 min 	 lr= 0.1 	 loss= 0.1789514706258408 	 error= 6.163194436918606 percent
# error rate on dev set = 27.65625 percent
#
# epoch= 173 	 time= 17.279989425341288 min 	 lr= 0.1 	 loss= 0.1852489531209523 	 error= 6.367631392045454 percent
# error rate on dev set = 27.51953125 percent
#
# epoch= 174 	 time= 17.379599344730376 min 	 lr= 0.1 	 loss= 0.18654369334266943 	 error= 6.462574970315803 percent
# error rate on dev set = 28.59375 percent
#
# epoch= 175 	 time= 17.479921678702038 min 	 lr= 0.1 	 loss= 0.20635492060418156 	 error= 7.022125544873151 percent
# error rate on dev set = 28.749999999999996 percent
#
# epoch= 176 	 time= 17.580949111779532 min 	 lr= 0.1 	 loss= 0.20863786912311547 	 error= 7.090682214633985 percent
# error rate on dev set = 28.085937500000004 percent
#
# epoch= 177 	 time= 17.68456264734268 min 	 lr= 0.1 	 loss= 0.19990289129782468 	 error= 6.836923923004758 percent
# error rate on dev set = 28.4375 percent
#
# epoch= 178 	 time= 17.78431971867879 min 	 lr= 0.1 	 loss= 0.19398869150741535 	 error= 6.704742732373151 percent
# error rate on dev set = 28.066406249999996 percent
#
# epoch= 179 	 time= 17.88651337623596 min 	 lr= 0.1 	 loss= 0.2147083190502599 	 error= 7.304736819456924 percent
# error rate on dev set = 26.992187499999996 percent
#
# epoch= 180 	 time= 17.986590520540872 min 	 lr= 0.1 	 loss= 0.1806539103325287 	 error= 6.382427787916227 percent
# error rate on dev set = 26.97265625 percent
#
# epoch= 181 	 time= 18.084044420719145 min 	 lr= 0.1 	 loss= 0.21539946120571007 	 error= 7.244564779102802 percent
# error rate on dev set = 28.59375 percent
#
# epoch= 182 	 time= 18.181353298823037 min 	 lr= 0.1 	 loss= 0.21043467160779983 	 error= 7.2287819602272725 percent
# error rate on dev set = 27.63671875 percent
#
# epoch= 183 	 time= 18.277692691485086 min 	 lr= 0.1 	 loss= 0.19473375341939655 	 error= 6.644817306236788 percent
# error rate on dev set = 28.3984375 percent
#
# epoch= 184 	 time= 18.375252123673757 min 	 lr= 0.1 	 loss= 0.21036920218135824 	 error= 7.1350714191794395 percent
# error rate on dev set = 29.00390625 percent
#
# epoch= 185 	 time= 18.471265041828154 min 	 lr= 0.1 	 loss= 0.21358223249924116 	 error= 7.222616791047833 percent
# error rate on dev set = 28.69140625 percent
#
# epoch= 186 	 time= 18.57292761405309 min 	 lr= 0.1 	 loss= 0.19747347638688303 	 error= 6.731869466602802 percent
# error rate on dev set = 28.41796875 percent
#
# epoch= 187 	 time= 18.671519033114116 min 	 lr= 0.1 	 loss= 0.1960623830937865 	 error= 6.5856317058205605 percent
# error rate on dev set = 28.574218750000004 percent
#
# epoch= 188 	 time= 18.76812342007955 min 	 lr= 0.1 	 loss= 0.18220743046946486 	 error= 6.269728527827696 percent
# error rate on dev set = 27.597656250000004 percent
#
# epoch= 189 	 time= 18.866111501057944 min 	 lr= 0.1 	 loss= 0.19073337684808808 	 error= 6.491674550554969 percent
# error rate on dev set = 28.80859375 percent
#
# epoch= 190 	 time= 18.96673885981242 min 	 lr= 0.1 	 loss= 0.18485868112607437 	 error= 6.2073370441794395 percent
# error rate on dev set = 29.0234375 percent
#
# epoch= 191 	 time= 19.067791704336802 min 	 lr= 0.1 	 loss= 0.20255844030444595 	 error= 6.93679963323203 percent
# error rate on dev set = 29.042968749999996 percent
#
# epoch= 192 	 time= 19.166267013549806 min 	 lr= 0.1 	 loss= 0.20107241222550246 	 error= 6.722498414191333 percent
# error rate on dev set = 27.988281250000004 percent
#
# epoch= 193 	 time= 19.266324786345162 min 	 lr= 0.1 	 loss= 0.1885725379371169 	 error= 6.436927870593288 percent
# error rate on dev set = 27.51953125 percent
#
# epoch= 194 	 time= 19.36081821123759 min 	 lr= 0.1 	 loss= 0.19052339736795562 	 error= 6.521267359229651 percent
# error rate on dev set = 28.183593750000004 percent
#
# epoch= 195 	 time= 19.46088973283768 min 	 lr= 0.1 	 loss= 0.19513985882936555 	 error= 6.713127361779864 percent
# error rate on dev set = 28.6328125 percent
#
# epoch= 196 	 time= 19.56060266494751 min 	 lr= 0.1 	 loss= 0.17372481772591444 	 error= 5.890694040466438 percent
# error rate on dev set = 27.695312500000004 percent
#
# epoch= 197 	 time= 19.663446617126464 min 	 lr= 0.1 	 loss= 0.1711152516813441 	 error= 5.752594294873151 percent
# error rate on dev set = 27.05078125 percent
#
# epoch= 198 	 time= 19.759180025259653 min 	 lr= 0.1 	 loss= 0.16286547048102049 	 error= 5.482313358648256 percent
# error rate on dev set = 28.085937500000004 percent
#
# epoch= 199 	 time= 19.86150642633438 min 	 lr= 0.1 	 loss= 0.18540656637527386 	 error= 6.289950284090909 percent
# error rate on dev set = 28.749999999999996 percent
#
# epoch= 200 	 time= 19.959123436609904 min 	 lr= 0.1 	 loss= 0.180146958689544 	 error= 6.1326152052391665 percent
# error rate on dev set = 27.734375 percent
#
# epoch= 201 	 time= 20.055725967884065 min 	 lr= 0.1 	 loss= 0.17062602066223256 	 error= 5.890447443181818 percent
# error rate on dev set = 26.816406250000004 percent
#
# epoch= 202 	 time= 20.15932023525238 min 	 lr= 0.1 	 loss= 0.18218244286254048 	 error= 6.159741956401954 percent
# error rate on dev set = 27.304687500000004 percent
#
# epoch= 203 	 time= 20.260619866847993 min 	 lr= 0.1 	 loss= 0.17985307357527994 	 error= 6.252466057511893 percent
# error rate on dev set = 27.2265625 percent
#
# epoch= 204 	 time= 20.36131284236908 min 	 lr= 0.1 	 loss= 0.17514725975607606 	 error= 6.031259860504757 percent
# error rate on dev set = 28.80859375 percent
#
# epoch= 205 	 time= 20.45795741478602 min 	 lr= 0.1 	 loss= 0.18000143114477396 	 error= 6.065538186918606 percent
# error rate on dev set = 28.33984375 percent
#
# epoch= 206 	 time= 20.558358705043794 min 	 lr= 0.1 	 loss= 0.16017126553395594 	 error= 5.424854006956925 percent
# error rate on dev set = 29.1015625 percent
#
# epoch= 207 	 time= 20.65990875164668 min 	 lr= 0.1 	 loss= 0.1705154502150518 	 error= 5.887981368736788 percent
# error rate on dev set = 28.066406249999996 percent
#
# epoch= 208 	 time= 20.75919998884201 min 	 lr= 0.1 	 loss= 0.18371098610276188 	 error= 6.202404912222515 percent
# error rate on dev set = 26.308593749999996 percent
#
# epoch= 209 	 time= 20.859638174374897 min 	 lr= 0.1 	 loss= 0.16713127741505476 	 error= 5.6122750890525905 percent
# error rate on dev set = 27.109375000000004 percent
#
# epoch= 210 	 time= 20.963168156147002 min 	 lr= 0.1 	 loss= 0.16800379982768474 	 error= 5.678119087083773 percent
# error rate on dev set = 26.816406250000004 percent
#
# epoch= 211 	 time= 21.057884081204733 min 	 lr= 0.1 	 loss= 0.15461781255858528 	 error= 5.350132184949788 percent
# error rate on dev set = 26.503906249999996 percent
#
# epoch= 212 	 time= 21.153980191548666 min 	 lr= 0.1 	 loss= 0.1535467722305012 	 error= 5.230527929961681 percent
# error rate on dev set = 28.53515625 percent
#
# epoch= 213 	 time= 21.24855632384618 min 	 lr= 0.1 	 loss= 0.1793055742746219 	 error= 6.120778095315804 percent
# error rate on dev set = 27.968749999999996 percent
#
# epoch= 214 	 time= 21.3446533203125 min 	 lr= 0.1 	 loss= 0.18535707342777064 	 error= 6.216461482373151 percent
# error rate on dev set = 26.503906249999996 percent
#
# epoch= 215 	 time= 21.442374634742738 min 	 lr= 0.1 	 loss= 0.16460944248617373 	 error= 5.603890459645878 percent
# error rate on dev set = 28.3984375 percent
#
# epoch= 216 	 time= 21.540689007441202 min 	 lr= 0.1 	 loss= 0.175023482138799 	 error= 5.940015393901954 percent
# error rate on dev set = 26.484375 percent
#
# epoch= 217 	 time= 21.64230887492498 min 	 lr= 0.1 	 loss= 0.16246175567026844 	 error= 5.60660313137553 percent
# error rate on dev set = 27.597656250000004 percent
#
# epoch= 218 	 time= 21.74422217607498 min 	 lr= 0.1 	 loss= 0.17576286950233308 	 error= 5.854936079545454 percent
# error rate on dev set = 27.94921875 percent
#
# epoch= 219 	 time= 21.842961418628693 min 	 lr= 0.1 	 loss= 0.18035734961317343 	 error= 6.168619797311046 percent
# error rate on dev set = 27.871093749999996 percent
#
# epoch= 220 	 time= 21.940426071484882 min 	 lr= 0.1 	 loss= 0.14404359459877014 	 error= 4.892676763913848 percent
# error rate on dev set = 27.05078125 percent
#
# epoch= 221 	 time= 22.039352881908417 min 	 lr= 0.1 	 loss= 0.1682917323407971 	 error= 5.694395117461681 percent
# error rate on dev set = 28.574218750000004 percent
#
# epoch= 222 	 time= 22.138463763395944 min 	 lr= 0.1 	 loss= 0.15253254484956746 	 error= 5.31905974176797 percent
# error rate on dev set = 28.281250000000004 percent
#
# epoch= 223 	 time= 22.23783278465271 min 	 lr= 0.1 	 loss= 0.17244509439280425 	 error= 5.72226167741147 percent
# error rate on dev set = 27.011718750000004 percent
#
# epoch= 224 	 time= 22.336789155006407 min 	 lr= 0.1 	 loss= 0.15046330652496015 	 error= 5.122514204545454 percent
# error rate on dev set = 27.83203125 percent
#
# epoch= 225 	 time= 22.43547043800354 min 	 lr= 0.1 	 loss= 0.1522023257460784 	 error= 5.277629806236788 percent
# error rate on dev set = 27.734375 percent
#
# epoch= 226 	 time= 22.531178021430968 min 	 lr= 0.1 	 loss= 0.1669433537383818 	 error= 5.677379261363636 percent
# error rate on dev set = 27.871093749999996 percent
#
# epoch= 227 	 time= 22.63108099301656 min 	 lr= 0.1 	 loss= 0.18541364481841976 	 error= 6.178730658509514 percent
# error rate on dev set = 26.85546875 percent
#
# epoch= 228 	 time= 22.73303189675013 min 	 lr= 0.1 	 loss= 0.17064306781288574 	 error= 5.688723159784621 percent
# error rate on dev set = 29.08203125 percent
#
# epoch= 229 	 time= 22.83119128147761 min 	 lr= 0.1 	 loss= 0.17170915824615143 	 error= 5.800189399583773 percent
# error rate on dev set = 29.58984375 percent
#
# epoch= 230 	 time= 22.93256866534551 min 	 lr= 0.1 	 loss= 0.16287829060192135 	 error= 5.4869988933205605 percent
# error rate on dev set = 27.4609375 percent
#
# epoch= 231 	 time= 23.03261001507441 min 	 lr= 0.1 	 loss= 0.1597902396460995 	 error= 5.456666275858879 percent
# error rate on dev set = 27.968749999999996 percent
#
# epoch= 232 	 time= 23.131712726751964 min 	 lr= 0.1 	 loss= 0.16967236990405415 	 error= 5.699080652133985 percent
# error rate on dev set = 26.93359375 percent
#
# epoch= 233 	 time= 23.22940322558085 min 	 lr= 0.1 	 loss= 0.15469594923144375 	 error= 5.277629806236788 percent
# error rate on dev set = 28.066406249999996 percent
#
# epoch= 234 	 time= 23.327202785015107 min 	 lr= 0.1 	 loss= 0.17453312704508955 	 error= 5.972320857373151 percent
# error rate on dev set = 28.30078125 percent
#
# epoch= 235 	 time= 23.428405539194742 min 	 lr= 0.1 	 loss= 0.16564330050129106 	 error= 5.57281801646406 percent
# error rate on dev set = 26.26953125 percent
#
# epoch= 236 	 time= 23.526379243532816 min 	 lr= 0.1 	 loss= 0.15349202689884062 	 error= 5.272697674279863 percent
# error rate on dev set = 25.9765625 percent
#
# epoch= 237 	 time= 23.62235188881556 min 	 lr= 0.1 	 loss= 0.15380244586743752 	 error= 5.184165879406712 percent
# error rate on dev set = 28.046875 percent
#
# epoch= 238 	 time= 23.719912747542065 min 	 lr= 0.1 	 loss= 0.16329414571042766 	 error= 5.464804291047833 percent
# error rate on dev set = 28.41796875 percent
#
# epoch= 239 	 time= 23.815890522797904 min 	 lr= 0.1 	 loss= 0.14813465063079176 	 error= 4.956794513220137 percent
# error rate on dev set = 28.02734375 percent
#
# epoch= 240 	 time= 23.916063694159188 min 	 lr= 0.1 	 loss= 0.15849681325595488 	 error= 5.389589257538319 percent
# error rate on dev set = 27.75390625 percent
#
# epoch= 241 	 time= 24.017959479490916 min 	 lr= 0.1 	 loss= 0.15499100941021673 	 error= 5.3161004558205605 percent
# error rate on dev set = 27.089843749999996 percent
#
# epoch= 242 	 time= 24.119263954957326 min 	 lr= 0.1 	 loss= 0.16867036450738934 	 error= 5.651732161641121 percent
# error rate on dev set = 28.261718749999996 percent
#
# epoch= 243 	 time= 24.22260986963908 min 	 lr= 0.1 	 loss= 0.1731012488334355 	 error= 5.829042382538319 percent
# error rate on dev set = 26.523437500000004 percent
#
# epoch= 244 	 time= 24.320286989212036 min 	 lr= 0.1 	 loss= 0.16193112026138062 	 error= 5.454200201413848 percent
# error rate on dev set = 26.718750000000004 percent
#
# epoch= 245 	 time= 24.423652736345925 min 	 lr= 0.1 	 loss= 0.1519429774700918 	 error= 5.183919265188954 percent
# error rate on dev set = 27.285156249999996 percent
#
# epoch= 246 	 time= 24.52711695432663 min 	 lr= 0.1 	 loss= 0.15032906965775925 	 error= 5.114869400858879 percent
# error rate on dev set = 27.24609375 percent
#
# epoch= 247 	 time= 24.627159106731416 min 	 lr= 0.1 	 loss= 0.15440304700115864 	 error= 5.24581755426797 percent
# error rate on dev set = 26.6796875 percent
#
# epoch= 248 	 time= 24.72469668785731 min 	 lr= 0.1 	 loss= 0.1567596551665867 	 error= 5.3592566231435 percent
# error rate on dev set = 26.07421875 percent
#
# epoch= 249 	 time= 24.8282252351443 min 	 lr= 0.1 	 loss= 0.15986685970247808 	 error= 5.422387932511893 percent
# error rate on dev set = 28.964843750000004 percent
#
# epoch= 250 	 time= 24.930854745705922 min 	 lr= 0.1 	 loss= 0.14706004129468717 	 error= 5.036695081401954 percent
# error rate on dev set = 27.1484375 percent
#
# epoch= 251 	 time= 25.027052625020346 min 	 lr= 0.1 	 loss= 0.139086028883784 	 error= 4.84335542741147 percent
# error rate on dev set = 28.14453125 percent
#
# epoch= 252 	 time= 25.132078941663107 min 	 lr= 0.1 	 loss= 0.15049480880737642 	 error= 5.166163583370772 percent
# error rate on dev set = 28.046875 percent
#
# epoch= 253 	 time= 25.22903195222219 min 	 lr= 0.1 	 loss= 0.14227413370231676 	 error= 4.9190636893565 percent
# error rate on dev set = 26.54296875 percent
#
# epoch= 254 	 time= 25.332672293980917 min 	 lr= 0.1 	 loss= 0.17334870884025638 	 error= 5.721028640188954 percent
# error rate on dev set = 29.9609375 percent
#
# epoch= 255 	 time= 25.434588523705802 min 	 lr= 0.1 	 loss= 0.1699219288897108 	 error= 5.775775337083773 percent
# error rate on dev set = 28.4375 percent
#
# epoch= 256 	 time= 25.534472636381786 min 	 lr= 0.1 	 loss= 0.14059281292032788 	 error= 4.807104238054969 percent
# error rate on dev set = 27.382812499999996 percent
#
# epoch= 257 	 time= 25.63511428038279 min 	 lr= 0.1 	 loss= 0.14892214741981166 	 error= 5.086263015188954 percent
# error rate on dev set = 27.55859375 percent
#
# epoch= 258 	 time= 25.735702308019004 min 	 lr= 0.1 	 loss= 0.16264660853299906 	 error= 5.446801995011893 percent
# error rate on dev set = 26.621093750000004 percent
#
# epoch= 259 	 time= 25.83360050916672 min 	 lr= 0.1 	 loss= 0.14542874123964628 	 error= 4.975783215327696 percent
# error rate on dev set = 27.207031250000004 percent
#
# epoch= 260 	 time= 25.93466115395228 min 	 lr= 0.1 	 loss= 0.16494230494241824 	 error= 5.598958327688954 percent
# error rate on dev set = 26.8359375 percent
#
# epoch= 261 	 time= 26.02905919154485 min 	 lr= 0.1 	 loss= 0.15125747994435104 	 error= 5.198962275277485 percent
# error rate on dev set = 28.964843750000004 percent
#
# epoch= 262 	 time= 26.126772805054983 min 	 lr= 0.1 	 loss= 0.1593916683923453 	 error= 5.323252048004757 percent
# error rate on dev set = 27.75390625 percent
#
# epoch= 263 	 time= 26.230632527669272 min 	 lr= 0.1 	 loss= 0.15471203918357126 	 error= 5.285767838358879 percent
# error rate on dev set = 27.12890625 percent
#
# epoch= 264 	 time= 26.33112492163976 min 	 lr= 0.1 	 loss= 0.13753402752759444 	 error= 4.6157374470071355 percent
# error rate on dev set = 27.011718750000004 percent
#
# epoch= 265 	 time= 26.43191959063212 min 	 lr= 0.1 	 loss= 0.1441431381337514 	 error= 4.828065820038319 percent
# error rate on dev set = 27.51953125 percent
#
# epoch= 266 	 time= 26.531667149066926 min 	 lr= 0.1 	 loss= 0.14822187985886226 	 error= 5.037434890188954 percent
# error rate on dev set = 26.34765625 percent
#
# epoch= 267 	 time= 26.63131949901581 min 	 lr= 0.1 	 loss= 0.13779373949562962 	 error= 4.7481652518565 percent
# error rate on dev set = 27.16796875 percent
#
# epoch= 268 	 time= 26.73550682067871 min 	 lr= 0.1 	 loss= 0.1336757465350357 	 error= 4.560250941325317 percent
# error rate on dev set = 26.93359375 percent
#
# epoch= 269 	 time= 26.834569374720257 min 	 lr= 0.1 	 loss= 0.12088967415250161 	 error= 4.1770241477272725 percent
# error rate on dev set = 27.109375000000004 percent
#
# epoch= 270 	 time= 26.928469196955362 min 	 lr= 0.1 	 loss= 0.15017219743987714 	 error= 5.165670371868393 percent
# error rate on dev set = 26.718750000000004 percent
#
# epoch= 271 	 time= 27.027776984373727 min 	 lr= 0.1 	 loss= 0.16723362925801089 	 error= 5.640634860504757 percent
# error rate on dev set = 27.792968750000004 percent
#
# epoch= 272 	 time= 27.125944519042967 min 	 lr= 0.1 	 loss= 0.1385627736083486 	 error= 4.810310138220137 percent
# error rate on dev set = 26.816406250000004 percent
#
# epoch= 273 	 time= 27.225864263375602 min 	 lr= 0.1 	 loss= 0.1705963754899461 	 error= 5.772816051136364 percent
# error rate on dev set = 26.7578125 percent
#
# epoch= 274 	 time= 27.330685639381407 min 	 lr= 0.1 	 loss= 0.16388105330142108 	 error= 5.507713861086152 percent
# error rate on dev set = 27.207031250000004 percent
#
# epoch= 275 	 time= 27.432480402787526 min 	 lr= 0.1 	 loss= 0.1305152500916103 	 error= 4.469499686224894 percent
# error rate on dev set = 26.8359375 percent
#
# epoch= 276 	 time= 27.527221977710724 min 	 lr= 0.1 	 loss= 0.1130758789526722 	 error= 3.929924236779863 percent
# error rate on dev set = 27.089843749999996 percent
#
# epoch= 277 	 time= 27.623154691855113 min 	 lr= 0.1 	 loss= 0.12254641370170495 	 error= 4.212782108648256 percent
# error rate on dev set = 26.699218749999996 percent
#
# epoch= 278 	 time= 27.72413763999939 min 	 lr= 0.1 	 loss= 0.1421960461884737 	 error= 4.79156801646406 percent
# error rate on dev set = 27.109375000000004 percent
#
# epoch= 279 	 time= 27.8294544617335 min 	 lr= 0.1 	 loss= 0.14863022010434757 	 error= 4.925722070038319 percent
# error rate on dev set = 28.2421875 percent
#
# epoch= 280 	 time= 27.92790965239207 min 	 lr= 0.1 	 loss= 0.1641903263410892 	 error= 5.541005764495243 percent
# error rate on dev set = 27.187499999999996 percent
#
# epoch= 281 	 time= 28.028567175070446 min 	 lr= 0.1 	 loss= 0.11839671359947798 	 error= 4.007358747449788 percent
# error rate on dev set = 26.699218749999996 percent
#
# epoch= 282 	 time= 28.128402145703635 min 	 lr= 0.1 	 loss= 0.127964370820502 	 error= 4.410560683093288 percent
# error rate on dev set = 26.640625 percent
#
# epoch= 283 	 time= 28.224033919970193 min 	 lr= 0.1 	 loss= 0.17502458961892195 	 error= 5.895379575138742 percent
# error rate on dev set = 26.38671875 percent
#
# epoch= 284 	 time= 28.322915577888487 min 	 lr= 0.1 	 loss= 0.1710560324347832 	 error= 5.765911056236788 percent
# error rate on dev set = 27.16796875 percent
#
# epoch= 285 	 time= 28.421247152487435 min 	 lr= 0.1 	 loss= 0.15546647619075057 	 error= 5.2048808302391665 percent
# error rate on dev set = 27.109375000000004 percent
#
# epoch= 286 	 time= 28.516461245218913 min 	 lr= 0.1 	 loss= 0.13784528507808733 	 error= 4.661113074557348 percent
# error rate on dev set = 26.5625 percent
#
# epoch= 287 	 time= 28.61828285853068 min 	 lr= 0.1 	 loss= 0.13944662979338318 	 error= 4.795513725416227 percent
# error rate on dev set = 27.34375 percent
#
# epoch= 288 	 time= 28.722183235486348 min 	 lr= 0.1 	 loss= 0.14213832276238297 	 error= 4.943724349141121 percent
# error rate on dev set = 26.113281249999996 percent
#
# epoch= 289 	 time= 28.826242502530416 min 	 lr= 0.1 	 loss= 0.13466176777993413 	 error= 4.646563292904333 percent
# error rate on dev set = 26.46484375 percent
#
# epoch= 290 	 time= 28.92921511332194 min 	 lr= 0.1 	 loss= 0.15891387120989914 	 error= 5.401426367461681 percent
# error rate on dev set = 27.91015625 percent
#
# epoch= 291 	 time= 29.04841665029526 min 	 lr= 0.1 	 loss= 0.15323464213658802 	 error= 5.238172733648256 percent
# error rate on dev set = 26.328125000000004 percent
#
# epoch= 292 	 time= 29.229874432086945 min 	 lr= 0.1 	 loss= 0.14365168461914768 	 error= 5.080837671729651 percent
# error rate on dev set = 26.308593749999996 percent
#
# epoch= 293 	 time= 29.410712397098543 min 	 lr= 0.1 	 loss= 0.156759639789181 	 error= 5.432745424861258 percent
# error rate on dev set = 26.308593749999996 percent
#
# epoch= 294 	 time= 29.590892533461254 min 	 lr= 0.1 	 loss= 0.1569754043911499 	 error= 5.246557363054969 percent
# error rate on dev set = 27.675781249999996 percent
#
# epoch= 295 	 time= 29.769797813892364 min 	 lr= 0.1 	 loss= 0.15151845274323766 	 error= 5.1291725852272725 percent
# error rate on dev set = 28.203125 percent
#
# epoch= 296 	 time= 29.949762058258056 min 	 lr= 0.1 	 loss= 0.14722477186428892 	 error= 5.0468059426004235 percent
# error rate on dev set = 26.97265625 percent
#
# epoch= 297 	 time= 30.11240175565084 min 	 lr= 0.1 	 loss= 0.13904296526346693 	 error= 4.758029515770349 percent
# error rate on dev set = 26.796874999999996 percent
#
# ...
#
# epoch= 313 	 time= 31.917807006835936 min 	 lr= 0.1 	 loss= 0.15346070435638962 	 error= 5.271464637057348 percent
# error rate on dev set = 25.5859375 percent
#
# epoch= 314 	 time= 32.042115437984464 min 	 lr= 0.1 	 loss= 0.14314421966925941 	 error= 4.776031794873151 percent
# error rate on dev set = 27.65625 percent
#
# epoch= 315 	 time= 32.166436445713046 min 	 lr= 0.1 	 loss= 0.14433607053731315 	 error= 4.920296709645878 percent
# error rate on dev set = 26.308593749999996 percent
#
# epoch= 316 	 time= 32.289281113942465 min 	 lr= 0.1 	 loss= 0.1318917038786987 	 error= 4.597241956401954 percent
# error rate on dev set = 26.46484375 percent
#
# epoch= 317 	 time= 32.41209785938263 min 	 lr= 0.1 	 loss= 0.13001010355285622 	 error= 4.3503886427391665 percent
# error rate on dev set = 27.675781249999996 percent
#
# epoch= 318 	 time= 32.53188426097234 min 	 lr= 0.1 	 loss= 0.10658406234473329 	 error= 3.627337837083773 percent
# error rate on dev set = 26.894531249999996 percent
#
# epoch= 319 	 time= 32.63765799999237 min 	 lr= 0.1 	 loss= 0.11419109972088005 	 error= 3.881589323282242 percent
# error rate on dev set = 25.95703125 percent
#
# epoch= 320 	 time= 32.74414934317271 min 	 lr= 0.1 	 loss= 0.12974907254630869 	 error= 4.388119466602802 percent
# error rate on dev set = 27.24609375 percent
#
# epoch= 321 	 time= 32.849524708588916 min 	 lr= 0.1 	 loss= 0.14085132931359112 	 error= 4.785402847284621 percent
# error rate on dev set = 28.30078125 percent
#
# epoch= 322 	 time= 32.95775347948074 min 	 lr= 0.1 	 loss= 0.1423540800301866 	 error= 4.850507019595667 percent
# error rate on dev set = 27.382812499999996 percent
#
# epoch= 323 	 time= 33.063053266207376 min 	 lr= 0.1 	 loss= 0.14284228114411235 	 error= 4.731149378825317 percent
# error rate on dev set = 26.07421875 percent
#
# epoch= 324 	 time= 33.16768102645874 min 	 lr= 0.1 	 loss= 0.14013086460446092 	 error= 4.748411849141121 percent
# error rate on dev set = 27.71484375 percent
#
# epoch= 325 	 time= 33.27233822743098 min 	 lr= 0.1 	 loss= 0.14218842422335662 	 error= 4.831518300554969 percent
# error rate on dev set = 25.09765625 percent
#
# epoch= 326 	 time= 33.378381458918255 min 	 lr= 0.1 	 loss= 0.13247295992914587 	 error= 4.480843584645878 percent
# error rate on dev set = 26.699218749999996 percent
#
# epoch= 327 	 time= 33.48295711278915 min 	 lr= 0.1 	 loss= 0.12732790325852958 	 error= 4.2842980643565 percent
# error rate on dev set = 26.718750000000004 percent
#
# epoch= 328 	 time= 33.58812563419342 min 	 lr= 0.1 	 loss= 0.1511426562104713 	 error= 5.030036700720137 percent
# error rate on dev set = 25.624999999999996 percent
#
# epoch= 329 	 time= 33.69348355929057 min 	 lr= 0.1 	 loss= 0.14062583898405798 	 error= 4.715613157234409 percent
# error rate on dev set = 26.132812500000004 percent
#
# epoch= 330 	 time= 33.798419686158496 min 	 lr= 0.1 	 loss= 0.12483953055925667 	 error= 4.32449494573203 percent
# error rate on dev set = 26.718750000000004 percent
#
# epoch= 331 	 time= 33.90367412964503 min 	 lr= 0.1 	 loss= 0.1251065750362944 	 error= 4.2842980643565 percent
# error rate on dev set = 26.46484375 percent
#
# epoch= 332 	 time= 34.00939450661341 min 	 lr= 0.1 	 loss= 0.13000049051532353 	 error= 4.438673840327696 percent
# error rate on dev set = 26.015624999999996 percent
#
# epoch= 333 	 time= 34.115169203281404 min 	 lr= 0.1 	 loss= 0.11320189345331694 	 error= 3.844598325138742 percent
# error rate on dev set = 25.742187500000004 percent
#
# epoch= 334 	 time= 34.220495458443956 min 	 lr= 0.1 	 loss= 0.1255178865500387 	 error= 4.2527323927391665 percent
# error rate on dev set = 26.503906249999996 percent
#
# epoch= 335 	 time= 34.32674521605174 min 	 lr= 0.1 	 loss= 0.1412984256590293 	 error= 4.746192388913848 percent
# error rate on dev set = 26.875 percent
#
# epoch= 336 	 time= 34.43254679441452 min 	 lr= 0.1 	 loss= 0.12239312350919301 	 error= 4.113892838358879 percent
# error rate on dev set = 26.0546875 percent
#
# epoch= 337 	 time= 34.53278365929921 min 	 lr= 0.1 	 loss= 0.1634555451508442 	 error= 5.446308783509514 percent
# error rate on dev set = 27.36328125 percent
#
# epoch= 338 	 time= 34.63476974964142 min 	 lr= 0.1 	 loss= 0.14737818953157825 	 error= 4.959753782234409 percent
# error rate on dev set = 27.011718750000004 percent
#
# epoch= 339 	 time= 34.74596701463064 min 	 lr= 0.1 	 loss= 0.1357301191892475 	 error= 4.615490849722515 percent
# error rate on dev set = 27.12890625 percent
#
# epoch= 340 	 time= 34.86374041239421 min 	 lr= 0.1 	 loss= 0.15883213208607314 	 error= 5.265546082095667 percent
# error rate on dev set = 27.421875 percent
#
# epoch= 341 	 time= 34.96933977206548 min 	 lr= 0.1 	 loss= 0.13721286680083722 	 error= 4.681828042322939 percent
# error rate on dev set = 26.7578125 percent
#
# epoch= 342 	 time= 35.07494123379389 min 	 lr= 0.1 	 loss= 0.12619267966047945 	 error= 4.366171478547833 percent
# error rate on dev set = 26.953125 percent
#
# epoch= 343 	 time= 35.18032728036245 min 	 lr= 0.1 	 loss= 0.10436499175954271 	 error= 3.6258581856434997 percent
# error rate on dev set = 25.136718749999996 percent
#
# epoch= 344 	 time= 35.295924131075544 min 	 lr= 0.1 	 loss= 0.11669418564997613 	 error= 3.9511324160478334 percent
# error rate on dev set = 26.816406250000004 percent
#
# epoch= 345 	 time= 35.41924404700597 min 	 lr= 0.1 	 loss= 0.12527853395493532 	 error= 4.2695016515525905 percent
# error rate on dev set = 27.0703125 percent
#
# epoch= 346 	 time= 35.53206233183543 min 	 lr= 0.1 	 loss= 0.12983569299632852 	 error= 4.339044744318182 percent
# error rate on dev set = 27.089843749999996 percent
#
# epoch= 347 	 time= 35.63831282059352 min 	 lr= 0.1 	 loss= 0.12311529970346866 	 error= 4.145705090327696 percent
# error rate on dev set = 27.32421875 percent
#
# epoch= 348 	 time= 35.74119661649068 min 	 lr= 0.1 	 loss= 0.1402683117035353 	 error= 4.805624603547833 percent
# error rate on dev set = 27.382812499999996 percent
#
# epoch= 349 	 time= 35.84912096261978 min 	 lr= 0.1 	 loss= 0.1472146627916531 	 error= 4.990826225416227 percent
# error rate on dev set = 25.820312499999996 percent
#
# epoch= 350 	 time= 35.96283700068792 min 	 lr= 0.1 	 loss= 0.12572966638783162 	 error= 4.303779977966438 percent
# error rate on dev set = 26.796874999999996 percent
#
# epoch= 351 	 time= 36.0752632856369 min 	 lr= 0.1 	 loss= 0.1426146847026592 	 error= 4.81894136491147 percent
# error rate on dev set = 27.109375000000004 percent
#
# epoch= 352 	 time= 36.18646035194397 min 	 lr= 0.1 	 loss= 0.13950549882032315 	 error= 4.722024940631607 percent
# error rate on dev set = 26.5625 percent
#
# epoch= 353 	 time= 36.30087082783381 min 	 lr= 0.1 	 loss= 0.13602642085805366 	 error= 4.644097218459303 percent
# error rate on dev set = 25.644531250000004 percent
#
# epoch= 354 	 time= 36.40578578313192 min 	 lr= 0.1 	 loss= 0.10767125778577545 	 error= 3.614760884507136 percent
# error rate on dev set = 26.503906249999996 percent
#
# epoch= 355 	 time= 36.51124497652054 min 	 lr= 0.1 	 loss= 0.12325914917429062 	 error= 4.154582931236788 percent
# error rate on dev set = 28.164062499999996 percent
#
# epoch= 356 	 time= 36.619086515903476 min 	 lr= 0.1 	 loss= 0.136511470857923 	 error= 4.602913897145878 percent
# error rate on dev set = 26.54296875 percent
#
# epoch= 357 	 time= 36.7252899646759 min 	 lr= 0.1 	 loss= 0.13329595778222111 	 error= 4.5195608484474095 percent
# error rate on dev set = 27.500000000000004 percent
#
# epoch= 358 	 time= 36.83008451064428 min 	 lr= 0.1 	 loss= 0.12446812739257108 	 error= 4.195026426830075 percent
# error rate on dev set = 26.07421875 percent
#
# epoch= 359 	 time= 36.93592962026596 min 	 lr= 0.1 	 loss= 0.14311608839356763 	 error= 4.7881155359474095 percent
# error rate on dev set = 27.675781249999996 percent
#
# epoch= 360 	 time= 37.04141092300415 min 	 lr= 0.1 	 loss= 0.12555393829560754 	 error= 4.341017590327696 percent
# error rate on dev set = 26.210937499999996 percent
#
# epoch= 361 	 time= 37.146773278713226 min 	 lr= 0.1 	 loss= 0.13140583478591658 	 error= 4.378748414191333 percent
# error rate on dev set = 25.87890625 percent
#
# epoch= 362 	 time= 37.25188084046046 min 	 lr= 0.1 	 loss= 0.1397622749209404 	 error= 4.685033925554969 percent
# error rate on dev set = 25.624999999999996 percent
#
# epoch= 363 	 time= 37.35673709313075 min 	 lr= 0.1 	 loss= 0.12777937699998307 	 error= 4.3503886427391665 percent
# error rate on dev set = 26.796874999999996 percent
#
# epoch= 364 	 time= 37.462707277139025 min 	 lr= 0.1 	 loss= 0.14352125350639902 	 error= 4.80636442926797 percent
# error rate on dev set = 26.328125000000004 percent
#
# epoch= 365 	 time= 37.57619525591532 min 	 lr= 0.1 	 loss= 0.12847424390598794 	 error= 4.270488074557348 percent
# error rate on dev set = 26.113281249999996 percent
#
# epoch= 366 	 time= 37.681759150822955 min 	 lr= 0.1 	 loss= 0.107102050953968 	 error= 3.612294826995243 percent
# error rate on dev set = 26.09375 percent
#
# epoch= 367 	 time= 37.786780361334486 min 	 lr= 0.1 	 loss= 0.13529786574442618 	 error= 4.712653888220137 percent
# error rate on dev set = 25.48828125 percent
#
# epoch= 368 	 time= 37.88522829214732 min 	 lr= 0.1 	 loss= 0.13705621708438478 	 error= 4.639904912222515 percent
# error rate on dev set = 26.6796875 percent
#
# epoch= 369 	 time= 37.9865629474322 min 	 lr= 0.1 	 loss= 0.14769548025320878 	 error= 5.092428184368393 percent
# error rate on dev set = 25.078125 percent
#
# epoch= 370 	 time= 38.09445389111837 min 	 lr= 0.1 	 loss= 0.11481568626847795 	 error= 3.9252387190406974 percent
# error rate on dev set = 26.85546875 percent
#
# epoch= 371 	 time= 38.20044845342636 min 	 lr= 0.1 	 loss= 0.1073396594305946 	 error= 3.6665482954545454 percent
# error rate on dev set = 25.351562500000004 percent
#
# epoch= 372 	 time= 38.305640176932016 min 	 lr= 0.1 	 loss= 0.13207241270521825 	 error= 4.603407108648256 percent
# error rate on dev set = 25.644531250000004 percent
#
# epoch= 373 	 time= 38.41100027163824 min 	 lr= 0.1 	 loss= 0.1388385282533074 	 error= 4.799212837083773 percent
# error rate on dev set = 27.32421875 percent
#
# epoch= 374 	 time= 38.51639851729075 min 	 lr= 0.1 	 loss= 0.13327415225053715 	 error= 4.646070081401954 percent
# error rate on dev set = 26.25 percent
#
# epoch= 375 	 time= 38.62100253105164 min 	 lr= 0.1 	 loss= 0.1266505266010592 	 error= 4.26308988508853 percent
# error rate on dev set = 25.078125 percent
#
# epoch= 376 	 time= 38.73289535442988 min 	 lr= 0.1 	 loss= 0.12647546514530073 	 error= 4.333372786641121 percent
# error rate on dev set = 27.34375 percent
#
# epoch= 377 	 time= 38.848174508412676 min 	 lr= 0.1 	 loss= 0.12285131428771737 	 error= 4.23941563137553 percent
# error rate on dev set = 27.0703125 percent
#
# epoch= 378 	 time= 38.952891210714974 min 	 lr= 0.1 	 loss= 0.11464417205107483 	 error= 3.9469401098110457 percent
# error rate on dev set = 27.695312500000004 percent
#
# epoch= 379 	 time= 39.05536381403605 min 	 lr= 0.1 	 loss= 0.1244721089341593 	 error= 4.106987843459303 percent
# error rate on dev set = 25.859375 percent
#
# epoch= 380 	 time= 39.161134990056354 min 	 lr= 0.1 	 loss= 0.1344607264459641 	 error= 4.460128633813425 percent
# error rate on dev set = 26.406249999999996 percent
#
# epoch= 381 	 time= 39.263510624567665 min 	 lr= 0.1 	 loss= 0.11380851041229273 	 error= 3.893919661641121 percent
# error rate on dev set = 25.5859375 percent
#
# epoch= 382 	 time= 39.36506001551946 min 	 lr= 0.1 	 loss= 0.12641979124270042 	 error= 4.188861274583773 percent
# error rate on dev set = 25.60546875 percent
#
# epoch= 383 	 time= 39.464536567529045 min 	 lr= 0.1 	 loss= 0.13852311799895356 	 error= 4.624122076413848 percent
# error rate on dev set = 26.2890625 percent
#
# epoch= 384 	 time= 39.57390499512355 min 	 lr= 0.1 	 loss= 0.1371259532911195 	 error= 4.552606137638742 percent
# error rate on dev set = 26.894531249999996 percent
#
# epoch= 385 	 time= 39.72686571677526 min 	 lr= 0.1 	 loss= 0.13105984481940555 	 error= 4.436947591602802 percent
# error rate on dev set = 26.93359375 percent
#
# epoch= 386 	 time= 39.90615737438202 min 	 lr= 0.1 	 loss= 0.11703120051375167 	 error= 4.018456048586152 percent
# error rate on dev set = 26.503906249999996 percent
#
# epoch= 387 	 time= 40.086112372080485 min 	 lr= 0.1 	 loss= 0.13892522151581943 	 error= 4.743726331401954 percent
# error rate on dev set = 26.894531249999996 percent
#
# epoch= 388 	 time= 40.26620859702428 min 	 lr= 0.1 	 loss= 0.14927249648396604 	 error= 5.0384213131937114 percent
# error rate on dev set = 25.820312499999996 percent
#
# epoch= 389 	 time= 40.44614072640737 min 	 lr= 0.1 	 loss= 0.13894158456770872 	 error= 4.673936624418606 percent
# error rate on dev set = 26.816406250000004 percent
#
# epoch= 390 	 time= 40.626526447137195 min 	 lr= 0.1 	 loss= 0.1288364295297387 	 error= 4.411300508813425 percent
# error rate on dev set = 26.132812500000004 percent
#
# epoch= 391 	 time= 40.80648843844732 min 	 lr= 0.1 	 loss= 0.12868921783625742 	 error= 4.381461085920984 percent
# error rate on dev set = 25.546875000000004 percent
#
# epoch= 392 	 time= 40.987382094065346 min 	 lr= 0.1 	 loss= 0.13589397625235672 	 error= 4.544714719734409 percent
# error rate on dev set = 26.34765625 percent
#
# epoch= 393 	 time= 41.16763581037522 min 	 lr= 0.1 	 loss= 0.1326364674287933 	 error= 4.4803503731435 percent
# error rate on dev set = 26.15234375 percent
#
# epoch= 394 	 time= 41.31531865199407 min 	 lr= 0.1 	 loss= 0.10071574167390777 	 error= 3.420188210227273 percent
# error rate on dev set = 26.3671875 percent
#
# epoch= 395 	 time= 41.46121618747711 min 	 lr= 0.1 	 loss= 0.12089858089827678 	 error= 4.096876965327696 percent
# error rate on dev set = 26.406249999999996 percent
#
# epoch= 396 	 time= 41.5976667602857 min 	 lr= 0.1 	 loss= 0.12456791690254415 	 error= 4.212535511363636 percent
# error rate on dev set = 26.523437500000004 percent
#
# epoch= 397 	 time= 41.701614276568094 min 	 lr= 0.1 	 loss= 0.14356064082081008 	 error= 4.832011512057348 percent
# error rate on dev set = 26.8359375 percent
#
# epoch= 398 	 time= 41.80954628785451 min 	 lr= 0.1 	 loss= 0.12590839875735005 	 error= 4.262843270870772 percent
# error rate on dev set = 25.644531250000004 percent
#
# epoch= 399 	 time= 41.91624444723129 min 	 lr= 0.1 	 loss= 0.13536557712888514 	 error= 4.485035907815804 percent
# error rate on dev set = 26.7578125 percent
#
# epoch= 400 	 time= 42.02015212774277 min 	 lr= 0.1 	 loss= 0.12911444170061837 	 error= 4.338058321313425 percent
# error rate on dev set = 26.09375 percent
#
# epoch= 401 	 time= 42.11466495990753 min 	 lr= 0.1 	 loss= 0.12597454969496044 	 error= 4.164447212083773 percent
# error rate on dev set = 26.93359375 percent
#
# epoch= 402 	 time= 42.21739364862442 min 	 lr= 0.1 	 loss= 0.13503849439703944 	 error= 4.5136422765525905 percent
# error rate on dev set = 26.484375 percent
#
# epoch= 403 	 time= 42.32654496828715 min 	 lr= 0.1 	 loss= 0.12996530267198317 	 error= 4.32770082896406 percent
# error rate on dev set = 26.601562499999996 percent
#
# epoch= 404 	 time= 42.48666743040085 min 	 lr= 0.1 	 loss= 0.1246005309830335 	 error= 4.244347780265591 percent
# error rate on dev set = 26.09375 percent
#
# epoch= 405 	 time= 42.6661744316419 min 	 lr= 0.1 	 loss= 0.1019236019346863 	 error= 3.492690572007136 percent
# error rate on dev set = 26.132812500000004 percent
#
# epoch= 406 	 time= 42.84611757993698 min 	 lr= 0.1 	 loss= 0.1188571257834238 	 error= 4.058406332677061 percent
# error rate on dev set = 26.230468750000004 percent
#
# epoch= 407 	 time= 43.02561488548915 min 	 lr= 0.1 	 loss= 0.12104705323211172 	 error= 4.169132729822939 percent
# error rate on dev set = 25.839843750000004 percent
#
# epoch= 408 	 time= 43.20650364160538 min 	 lr= 0.1 	 loss= 0.120324362101118 	 error= 4.107234457677061 percent
# error rate on dev set = 25.1171875 percent
#
# epoch= 409 	 time= 43.38713807662328 min 	 lr= 0.1 	 loss= 0.13894732435106893 	 error= 4.663825763220137 percent
# error rate on dev set = 25.37109375 percent
#
# epoch= 410 	 time= 43.56826620896657 min 	 lr= 0.1 	 loss= 0.11696949600644241 	 error= 3.9074830372225153 percent
# error rate on dev set = 25.703125 percent

# %%
# import matplotlib.pyplot as plt
# def show(X):
#     if X.dim() == 3 and X.size(0) == 3:
#         plt.imshow( np.transpose(  X.numpy() , (1, 2, 0))  )
#         plt.show()
#     elif X.dim() == 2:
#         plt.imshow(   X.numpy() , cmap='gray'  )
#         plt.show()
#     else:
#         print('WRONG TENSOR SIZE')

# %%
# def show_prob_cifar(p):


#     p=p.data.squeeze().numpy()

#     ft=15
#     label = ('airplane', 'automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship','Truck' )
#     #p=p.data.squeeze().numpy()
#     y_pos = np.arange(len(p))*1.2
#     target=2
#     width=0.9
#     col= 'blue'
#     #col='darkgreen'

#     plt.rcdefaults()
#     fig, ax = plt.subplots()

#     # the plot
#     ax.barh(y_pos, p, width , align='center', color=col)

#     ax.set_xlim([0, 1.3])
#     #ax.set_ylim([-0.8, len(p)*1.2-1+0.8])

#     # y label
#     ax.set_yticks(y_pos)
#     ax.set_yticklabels(label, fontsize=ft)
#     ax.invert_yaxis()  
#     #ax.set_xlabel('Performance')
#     #ax.set_title('How fast do you want to go today?')

#     # x label
#     ax.set_xticklabels([])
#     ax.set_xticks([])
#     #x_pos=np.array([0, 0.25 , 0.5 , 0.75 , 1])
#     #ax.set_xticks(x_pos)
#     #ax.set_xticklabels( [0, 0.25 , 0.5 , 0.75 , 1] , fontsize=15)

#     ax.spines['right'].set_visible(False)
#     ax.spines['top'].set_visible(False)
#     ax.spines['bottom'].set_visible(False)
#     ax.spines['left'].set_linewidth(4)


#     for i in range(len(p)):
#         str_nb="{0:.2f}".format(p[i])
#         ax.text( p[i] + 0.05 , y_pos[i] ,str_nb ,
#                  horizontalalignment='left', verticalalignment='center',
#                  transform=ax.transData, color= col,fontsize=ft)
#     plt.show()

# %%
# # choose a picture at random
# from random import randint
# idx=randint(0, 10000-1)
# im=test_data[idx]

# # diplay the picture
# show(im)

# # send to device, rescale, and view as a batch of 1 
# im = im.to(device)
# im= (im-mean) / std
# im=im.view(1,3,32,32)

# # feed it to the net and display the confidence scores
# scores =  model(im) 
# probs= F.softmax(scores, dim=1)
# show_prob_cifar(probs.cpu())
